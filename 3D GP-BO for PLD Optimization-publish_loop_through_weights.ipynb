# %% [markdown]
# # Setting up a 3D Bayesian optimization problem with gaussian process regression
#
# Jackson S. Bentley, Sumner B. Harris
# 09/01/25

# %%
# Step 1: Clean uninstall of conflicting packages
# !pip uninstall -y jax jaxlib ml-dtypes gpax

# Step 2: Install compatible versions
# !pip install jax==0.6.2 jaxlib==0.6.2 ml_dtypes==0.5.1

# Step 3: Install gpax version that supports jax>=0.6.2
# !pip install gpax==0.1.9

# Step 4: Force CPU use and test
import jax
import gpax

jax.config.update("jax_platform_name", "cpu")  # CPU only
gpax.utils.enable_x64()

print("✅ GPAX is ready with JAX version:", jax.__version__)
# Out:
# Found existing installation: jax 0.7.2
# Uninstalling jax-0.7.2:
#   Successfully uninstalled jax-0.7.2
# Found existing installation: jaxlib 0.7.2
# Uninstalling jaxlib-0.7.2:
#   Successfully uninstalled jaxlib-0.7.2
# Found existing installation: ml_dtypes 0.5.3
# Uninstalling ml_dtypes-0.5.3:
#   Successfully uninstalled ml_dtypes-0.5.3
# WARNING: Skipping gpax as it is not installed.
# Collecting jax==0.6.2
#   Downloading jax-0.6.2-py3-none-any.whl.metadata (13 kB)
# Collecting jaxlib==0.6.2
#   Downloading jaxlib-0.6.2-cp312-cp312-manylinux2014_x86_64.whl.metadata (1.3 kB)
# Collecting ml_dtypes==0.5.1
#   Downloading ml_dtypes-0.5.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (21 kB)
# Requirement already satisfied: numpy>=1.26 in /usr/local/lib/python3.12/dist-packages (from jax==0.6.2) (2.0.2)
# Requirement already satisfied: opt_einsum in /usr/local/lib/python3.12/dist-packages (from jax==0.6.2) (3.4.0)
# Requirement already satisfied: scipy>=1.12 in /usr/local/lib/python3.12/dist-packages (from jax==0.6.2) (1.16.2)
# Downloading jax-0.6.2-py3-none-any.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 27.1 MB/s eta 0:00:00
# Downloading jaxlib-0.6.2-cp312-cp312-manylinux2014_x86_64.whl (89.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 MB 8.5 MB/s eta 0:00:00
# Downloading ml_dtypes-0.5.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 101.4 MB/s eta 0:00:00
# Installing collected packages: ml_dtypes, jaxlib, jax
# Successfully installed jax-0.6.2 jaxlib-0.6.2 ml_dtypes-0.5.1
# Collecting gpax==0.1.9
#   Downloading gpax-0.1.9-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: matplotlib>=3.1.1 in /usr/local/lib/python3.12/dist-packages (from gpax==0.1.9) (3.10.0)
# Requirement already satisfied: jax>=0.6.2 in /usr/local/lib/python3.12/dist-packages (from gpax==0.1.9) (0.6.2)
# Requirement already satisfied: jaxlib>=0.6.2 in /usr/local/lib/python3.12/dist-packages (from gpax==0.1.9) (0.6.2)
# Collecting numpyro>=0.18.0 (from gpax==0.1.9)
#   Downloading numpyro-0.19.0-py3-none-any.whl.metadata (37 kB)
# Collecting dm-haiku>=0.0.14 (from gpax==0.1.9)
#   Downloading dm_haiku-0.0.15-py3-none-any.whl.metadata (19 kB)
# Collecting jaxopt>=0.8.5 (from gpax==0.1.9)
#   Downloading jaxopt-0.8.5-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: flax>=0.10.7 in /usr/local/lib/python3.12/dist-packages (from gpax==0.1.9) (0.10.7)
# Requirement already satisfied: absl-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from dm-haiku>=0.0.14->gpax==0.1.9) (1.4.0)
# Collecting jmp>=0.0.2 (from dm-haiku>=0.0.14->gpax==0.1.9)
#   Downloading jmp-0.0.4-py3-none-any.whl.metadata (8.9 kB)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.12/dist-packages (from dm-haiku>=0.0.14->gpax==0.1.9) (2.0.2)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.12/dist-packages (from dm-haiku>=0.0.14->gpax==0.1.9) (0.9.0)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.12/dist-packages (from flax>=0.10.7->gpax==0.1.9) (1.1.2)
# Requirement already satisfied: optax in /usr/local/lib/python3.12/dist-packages (from flax>=0.10.7->gpax==0.1.9) (0.2.6)
# Requirement already satisfied: orbax-checkpoint in /usr/local/lib/python3.12/dist-packages (from flax>=0.10.7->gpax==0.1.9) (0.11.26)
# Requirement already satisfied: tensorstore in /usr/local/lib/python3.12/dist-packages (from flax>=0.10.7->gpax==0.1.9) (0.1.78)
# Requirement already satisfied: rich>=11.1 in /usr/local/lib/python3.12/dist-packages (from flax>=0.10.7->gpax==0.1.9) (13.9.4)
# Requirement already satisfied: typing_extensions>=4.2 in /usr/local/lib/python3.12/dist-packages (from flax>=0.10.7->gpax==0.1.9) (4.15.0)
# Requirement already satisfied: PyYAML>=5.4.1 in /usr/local/lib/python3.12/dist-packages (from flax>=0.10.7->gpax==0.1.9) (6.0.3)
# Requirement already satisfied: treescope>=0.1.7 in /usr/local/lib/python3.12/dist-packages (from flax>=0.10.7->gpax==0.1.9) (0.1.10)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from jax>=0.6.2->gpax==0.1.9) (0.5.1)
# Requirement already satisfied: opt_einsum in /usr/local/lib/python3.12/dist-packages (from jax>=0.6.2->gpax==0.1.9) (3.4.0)
# Requirement already satisfied: scipy>=1.12 in /usr/local/lib/python3.12/dist-packages (from jax>=0.6.2->gpax==0.1.9) (1.16.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.1.1->gpax==0.1.9) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.1.1->gpax==0.1.9) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.1.1->gpax==0.1.9) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.1.1->gpax==0.1.9) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.1.1->gpax==0.1.9) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.1.1->gpax==0.1.9) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.1.1->gpax==0.1.9) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.1.1->gpax==0.1.9) (2.9.0.post0)
# Requirement already satisfied: multipledispatch in /usr/local/lib/python3.12/dist-packages (from numpyro>=0.18.0->gpax==0.1.9) (1.0.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from numpyro>=0.18.0->gpax==0.1.9) (4.67.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.1.1->gpax==0.1.9) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=11.1->flax>=0.10.7->gpax==0.1.9) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=11.1->flax>=0.10.7->gpax==0.1.9) (2.19.2)
# Requirement already satisfied: chex>=0.1.87 in /usr/local/lib/python3.12/dist-packages (from optax->flax>=0.10.7->gpax==0.1.9) (0.1.90)
# Requirement already satisfied: etils[epath,epy] in /usr/local/lib/python3.12/dist-packages (from orbax-checkpoint->flax>=0.10.7->gpax==0.1.9) (1.13.0)
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.12/dist-packages (from orbax-checkpoint->flax>=0.10.7->gpax==0.1.9) (1.6.0)
# Requirement already satisfied: aiofiles in /usr/local/lib/python3.12/dist-packages (from orbax-checkpoint->flax>=0.10.7->gpax==0.1.9) (24.1.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from orbax-checkpoint->flax>=0.10.7->gpax==0.1.9) (5.29.5)
# Requirement already satisfied: humanize in /usr/local/lib/python3.12/dist-packages (from orbax-checkpoint->flax>=0.10.7->gpax==0.1.9) (4.14.0)
# Requirement already satisfied: simplejson>=3.16.0 in /usr/local/lib/python3.12/dist-packages (from orbax-checkpoint->flax>=0.10.7->gpax==0.1.9) (3.20.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from orbax-checkpoint->flax>=0.10.7->gpax==0.1.9) (5.9.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from chex>=0.1.87->optax->flax>=0.10.7->gpax==0.1.9) (75.2.0)
# Requirement already satisfied: toolz>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from chex>=0.1.87->optax->flax>=0.10.7->gpax==0.1.9) (0.12.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1->flax>=0.10.7->gpax==0.1.9) (0.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from etils[epath,epy]->orbax-checkpoint->flax>=0.10.7->gpax==0.1.9) (2025.3.0)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.12/dist-packages (from etils[epath,epy]->orbax-checkpoint->flax>=0.10.7->gpax==0.1.9) (6.5.2)
# Requirement already satisfied: zipp in /usr/local/lib/python3.12/dist-packages (from etils[epath,epy]->orbax-checkpoint->flax>=0.10.7->gpax==0.1.9) (3.23.0)
# Downloading gpax-0.1.9-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.0/78.0 kB 4.9 MB/s eta 0:00:00
# Downloading dm_haiku-0.0.15-py3-none-any.whl (374 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.1/374.1 kB 14.3 MB/s eta 0:00:00
# Downloading jaxopt-0.8.5-py3-none-any.whl (172 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.4/172.4 kB 11.6 MB/s eta 0:00:00
# Downloading numpyro-0.19.0-py3-none-any.whl (370 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 370.9/370.9 kB 15.0 MB/s eta 0:00:00
# Downloading jmp-0.0.4-py3-none-any.whl (18 kB)
# Installing collected packages: jmp, dm-haiku, numpyro, jaxopt, gpax
# Successfully installed dm-haiku-0.0.15 gpax-0.1.9 jaxopt-0.8.5 jmp-0.0.4 numpyro-0.19.0
# /usr/local/lib/python3.12/dist-packages/jaxlib/plugin_support.py:71: RuntimeWarning: JAX plugin jax_cuda12_plugin version 0.7.2 is installed, but it is not compatible with the installed jaxlib version 0.6.2, so it will not be used.
#   warnings.warn(
# ✅ GPAX is ready with JAX version: 0.6.2

# %%
# Define a degree symbol for later plotting
deg_sgn = '\N{DEGREE SIGN}'

# %% [markdown]
# # Starting from scratch gpbo weighting loop: only looping through n & k (deviation from out-of-plane lattice parameter & integrated LaVO4 intensity)

# %%
# Script that:
# - Loads Excel data
# - Builds the 3D grid (Pressure (log10), Temperature, Fluence)
# - Loops over n,k in {1,2,3} (m=l=1), computes y_train for each weight set
# - Retrains the gpax viGP for each (n,k) from scratch
# - Predicts across the full 3D grid, finds the best predicted point and best measured point
# - Saves a results table, histogram, and an interactive Plotly 3D scatter of best points
#
# Notes:
# - This script intentionally does NOT plot the full GP maps for every (n,k) to save time.
#   You can enable per-run plotting by setting `plot_each_run = True`.
# - Speed tips: reduce grid resolution (larger step sizes) or run fewer HMC samples (if you
#   expose fit arguments). Avoid running multiple GP fits simultaneously (JAX + multiprocessing
#   can deadlock).

# %%
# Install (uncomment if needed)
# NOTE: gpax may be a private package in your environment. If gpax is installed locally, skip install.
# !pip install gpax plotly openpyxl numpyro

# %%
# Imports and global settings
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from itertools import product
from pathlib import Path

import jax
import jax.numpy as jnp
import gpax

# Enable 64-bit (same as your previous cell)
gpax.utils.enable_x64()

# Plotly for interactive 3D
import plotly.graph_objects as go

# Colab file upload helper
try:
    from google.colab import files
except Exception:
    files = None


LVO_c_lit = 3.945 # out-of-plane lattice parameter from literature

# %%
# --- Helper functions (normalize / inverse normalize / save/load) ---

def normalize(data, min_val, max_val):
    return (data - min_val) / (max_val - min_val)


def inverse_normalize(norm_data, min_val, max_val):
    return norm_data * (max_val - min_val) + min_val


def save_data(
    file_name,
    X_train, y_train,
    X_test,
    x1, x2, x3,
    y_pred, y_sampled,
    acq, next_point,
    running_best,
    iteration
):
    np.savez(
        file_name,
        X_train=X_train,
        y_train=y_train,
        X_test=X_test,
        x1=x1,
        x2=x2,
        x3=x3,
        y_pred=y_pred,
        y_sampled=y_sampled,
        acq=acq,
        next_point=next_point,
        running_best=running_best,
        iteration=iteration
    )


def load_data(file_name):
    ds = np.load(file_name, allow_pickle=True)
    return (
        ds['X_train'],
        ds['y_train'],
        ds['X_test'],
        ds['x1'],
        ds['x2'],
        ds['x3'],
        ds['y_pred'],
        ds['y_sampled'],
        ds['acq'],
        ds['next_point'],
        ds['running_best'],
        ds['iteration']
    )


def update_datapoints(X_new, y_new, X_train, y_train):
    X_train = jnp.append(X_train, X_new, axis=0)
    y_train = jnp.append(y_train, y_new, axis=0)
    return X_train, y_train

# Reuse plotting routine (matplotlib projections), pretty much unchanged.
# Note: this function references globals pressure_min, pressure_max, T_min, T_max, fluence_min, fluence_max
# which will be set after the grid build cell below.

def plot_3d_projections(
    field_flat,
    P_array,
    T_array,
    F_array,
    title: str,
    X_train: np.ndarray = None,
    y_train: np.ndarray = None,
    deg_sgn: str = '°'
):
    field = np.asarray(field_flat)
    nP, nT, nF = len(P_array), len(T_array), len(F_array)
    if field.size != nP * nT * nF:
        raise ValueError(f"field length {field.size} != {nP}*{nT}*{nF}")

    field3d = field.reshape(nP, nT, nF)
    proj_PT = field3d.mean(axis=2)
    proj_PF = field3d.mean(axis=1)
    proj_TF = field3d.mean(axis=0)

    fig, axs = plt.subplots(1, 3, figsize=(18, 6), dpi=200, constrained_layout=True)
    for ax in axs:
        ax.tick_params(axis='both', labelsize=12)
    font_title = 20
    font_label = 18
    font_tick = 14

    im0 = axs[0].pcolormesh(P_array, T_array, proj_PT.T, shading='auto', cmap='nipy_spectral')
    axs[0].set_xlabel('log$_{10}$ O$_2$ Partial Pressure (log$_{10}$ Torr)', fontsize=font_label)
    axs[0].set_ylabel(f'Deposition Temperature ({deg_sgn}C)', fontsize=font_label)
    axs[0].set_title(f'{title} → T vs P', fontsize=font_title)
    fig.colorbar(im0, ax=axs[0], orientation='vertical')

    im1 = axs[1].pcolormesh(P_array, F_array, proj_PF.T, shading='auto', cmap='nipy_spectral')
    axs[1].set_xlabel('log$_{10}$ O$_2$ Partial Pressure (log$_{10}$ Torr)', fontsize=font_label)
    axs[1].set_ylabel('Fluence (J/cm$^2$)', fontsize=font_label)
    axs[1].set_title(f'{title} → F vs P', fontsize=font_title)
    fig.colorbar(im1, ax=axs[1], orientation='vertical')

    im2 = axs[2].pcolormesh(T_array, F_array, proj_TF.T, shading='auto', cmap='nipy_spectral')
    axs[2].set_xlabel(f'Deposition Temperature ({deg_sgn}C)', fontsize=font_label)
    axs[2].set_ylabel('Fluence (J/cm$^2$)', fontsize=font_label)
    axs[2].set_title(f'{title} → F vs T', fontsize=font_title)
    fig.colorbar(im2, ax=axs[2], orientation='vertical')

    if X_train is not None and y_train is not None:
        P_train = inverse_normalize(X_train[:,0], pressure_min, pressure_max)
        T_train = inverse_normalize(X_train[:,1], T_min, T_max)
        F_train = inverse_normalize(X_train[:,2], fluence_min, fluence_max)
        y_vals  = y_train.flatten()

        scatter_kwargs = dict(c=y_vals, cmap='Reds', edgecolor='k', s=200, alpha=0.8)

        sc0 = axs[0].scatter(P_train, T_train, **scatter_kwargs)
        sc1 = axs[1].scatter(P_train, F_train, **scatter_kwargs)
        sc2 = axs[2].scatter(T_train, F_train, **scatter_kwargs)

        from mpl_toolkits.axes_grid1.inset_locator import inset_axes
        cbar_ax = inset_axes(
            axs[2],
            width="60%",
            height="5%",
            loc='upper left',
            bbox_to_anchor=(0.55, 0.3, 1, 1),
            bbox_transform=axs[2].transAxes,
            borderpad=0,
        )
        cbar = fig.colorbar(sc0, cax=cbar_ax, orientation='horizontal')
        cbar.set_label('Sample\nScores', fontsize=font_label)
        cbar.ax.tick_params(labelsize=font_tick)

    fig.suptitle(
    f"{title}: Min-Max Scaling\n"
    r"$y_{\mathrm{train}} = \alpha \cdot |c - 3.945| + \beta \cdot R_{RMS} + \gamma \cdot FWHM + \delta \cdot LaVO_{4}$" + "\n" +
    f"[α = {alpha}, β = {beta}, γ = {gamma}, δ = {delta}]",
    fontsize=16,
    fontweight='bold',
    y=1.17
    )
    plt.show()

# %%
# --- Build the 3D grid (pressures are represented as log10(pressure)) ---
# Pressure bounds
start, stop = 3e-8, 3e-4
num_points_per_decade = 10
total_decades = int(np.log10(stop / start))
total_points = total_decades * num_points_per_decade + 1

# Pressure array stored as log10(pressure)
Pressure = np.log10(np.geomspace(start, stop, num=total_points))
pressure_min, pressure_max = Pressure.min(), Pressure.max()

# Temperature
T_min, T_max, T_stepsize = 500, 835, 20
Temperature = np.arange(T_min, T_max, T_stepsize, dtype=np.float32)

# Fluence
fluence_min, fluence_max, fluence_stepsize = 0.8, 2.2, 0.1
Fluence = np.arange(fluence_min, fluence_max, fluence_stepsize, dtype=np.float32)

# Normalized grids
P_norm = normalize(Pressure, pressure_min, pressure_max)
T_norm = normalize(Temperature, T_min, T_max)
F_norm = normalize(Fluence, fluence_min, fluence_max)

# Meshgrid in normalized space
Pg, Tg, Fg = np.meshgrid(P_norm, T_norm, F_norm, indexing='ij')
P_flat = Pg.reshape(-1, 1)
T_flat = Tg.reshape(-1, 1)
F_flat = Fg.reshape(-1, 1)
points_3d = np.hstack((P_flat, T_flat, F_flat))

print('3D parameter space has size:', points_3d.shape)
print('Pressure points (log10):', Pressure.shape)
print('Temperature points:', Temperature.shape)
print('Fluence points:', Fluence.shape)
print('Example back-transformed Pressure (Torr):', 10**(Pressure[:3]))

# Convert X_test to jax array once for faster device transfer
X_test_jnp = jnp.asarray(points_3d)

# %%
# --- GP step function (wraps gpax.viGP) ---
import numpyro
from numpyro import distributions
from jax import random

# Optionally define priors here (you can tune these or set to None)
lengthscale_prior_dist = None
noise_prior_dist = None


def step_GP(X_measured, y_measured, X_unmeasured,
            noise_prior_dist=None,
            lengthscale_prior_dist=None):
    rng_key1, rng_key2 = gpax.utils.get_keys()

    # Convert to jax arrays
    X_measured_j = jnp.asarray(X_measured)
    y_measured_j = jnp.asarray(y_measured).ravel()

    gp_model = gpax.viGP(
        input_dim=3,
        kernel='Matern',
        noise_prior_dist=noise_prior_dist,
        lengthscale_prior_dist=lengthscale_prior_dist
    )

    print('Training Model (this may take some time).')
    # You can pass additional kwargs into .fit if gpax supports them (e.g., fewer HMC samples)
    gp_model.fit(rng_key1, X_measured_j, y_measured_j, jitter=1e-2)

    print('Getting Model Predictions.')
    y_pred, y_sampled = gp_model.predict_in_batches(
        rng_key2,
        X_unmeasured,
        noiseless=False,
        jitter=1e-2
    )

    print('Calculating acquisition.')
    acquisition = gpax.acquisition.EI(
        rng_key2,
        gp_model,
        X_unmeasured,
        maximize=False,
        recent_points=X_measured_j,
        noiseless=False,
        jitter=1e-2,
        penalty='delta'
    )

    print('Getting parameter samples.')
    paras = gp_model.get_samples()

    # Convert outputs back to numpy for convenience
    return np.asarray(acquisition), np.asarray(y_pred), np.asarray(y_sampled), paras

# %%
# --- Load Excel / Build seed points ---

# Option A: Set path directly (if you already uploaded the file to /content)
file_path = '/content/LaVO3_PLD_Parameters_working_pressure_fixed_cleaned_up_no_10nm_no_LaVO4_to_B38.xlsx'
df = pd.read_excel(file_path)

# Option B: Use files.upload() in Colab
if files is not None:
    print('If running in Colab: use files.upload() to upload Excel file.\nOr set file_path directly in the script.')

# We'll try to pick up a file in /content if one dropped there, otherwise use upload
content_files = list(Path('/content').glob('*.xlsx')) + list(Path('.').glob('*.xlsx'))
if len(content_files) == 0:
    if files is not None:
        uploaded = files.upload()
        # take the first uploaded file
        first = next(iter(uploaded.keys()))
        file_path = f'/content/{first}'
    else:
        raise FileNotFoundError('No .xlsx files found in working directory and files.upload() is unavailable.')
else:
    file_path = str(content_files[0])

print('Using Excel file:', file_path)

# Read sheet (adjust sheet_name if necessary)
df = pd.read_excel(file_path, sheet_name=0)

# Extract columns (fall back to alternative names if necessary)
# Use the exact column names from excel spreadsheet; if any KeyError occurs, inspect df.columns

colmap = {
    'Sample ID': 'Sample ID',
    'Date (YYMMDD)': 'Date (YYMMDD)',
    'Fluence': 'Fluence (J/cm2)',
    'O2 Pressure': 'O2 Pressure (Torr)',
    'Working pressure': 'Working pressure (Torr)',
}

# Try to access the columns listed earlier; adapt if column names differ
try:
    fluence = df['Fluence (J/cm2)'].values.astype(float)
    o2_pressure = df['O2 Pressure (Torr)'].values.astype(float)
    substrate_temp = df['Substrate Temp. (C) (based on average of temperature measured near substrate)'].values.astype(float)
    roughness = df['Roughness (nm) (standard deviation of height: 3x3 um, 2 Hz, 512 sam/l, B25 sub only = 0.147 )'].values.astype(float)
    c_lattice_parameter = df['C Lattice Parameter from Fringes (Å) (or 2Tw  peak position*)'].values.astype(float)
    fwhm_rocking_curve = df['FWHM (deg) (Gaussian fitting of rocking curve: B25: sub only, 1 twin=0.0050 )'].values.astype(float)
    integrated_intensity = df['Integrated LaVO4 Intensity: 48-51, normalized, x10^6 [B25 sub only= 4.7 (250520)]'].values.astype(float)
except Exception as e:
    print('Column name mismatch: please inspect df.columns')
    print(df.columns)
    raise e

# Build raw seed points array (physical values)
seed_points_raw = np.column_stack((o2_pressure, substrate_temp, fluence))

# Normalize seed points into [0,1]
seed_points = np.zeros_like(seed_points_raw, dtype=np.float32)
seed_points[:, 0] = normalize(np.log10(seed_points_raw[:, 0]), pressure_min, pressure_max)
seed_points[:, 1] = normalize(seed_points_raw[:, 1], T_min, T_max)
seed_points[:, 2] = normalize(seed_points_raw[:, 2], fluence_min, fluence_max)

# initial X_train (normalized) and placeholders
X_train_initial = seed_points

# NOTE: y_train will be recalculated inside the loop for each (n,k)

# %%
# --- Main loop over weight combinations (n,k) ---
results = []

# Control flags
plot_each_run = False   # set True if you want to plot the GP results for each (n,k)
save_checkpoints = True # save a .npz checkpoint per run

for n, k in product([1,2,3], repeat=2):
    print('\n' + '='*60)
    print(f'Running weights: n={n}, k={k} (m=l=1)')
    m = 1
    l = 1
    alpha = 6.0606 * n
    beta = 0.0876 * m
    gamma = 4.3879 * l
    delta = 0.0338 * k

    # Compute y components and full target
    lattice_parameter_mismatch = np.abs(c_lattice_parameter - LVO_c_lit)
    y_1 = alpha * lattice_parameter_mismatch
    y_2 = beta * roughness
    y_3 = gamma * fwhm_rocking_curve
    y_4 = delta * integrated_intensity
    y_train_full = (y_1 + y_2 + y_3 + y_4).astype(float)

    # Handle NaNs and infs
    mask_good = np.isfinite(y_train_full)
    if not np.all(mask_good):
        print(f'Warning: {np.count_nonzero(~mask_good)} bad rows in y_train; dropping them from X_train.')

    X_train_masked = X_train_initial[mask_good]
    y_train_masked = y_train_full[mask_good]

    # convert to jax arrays when passing to step_GP
    acq, y_pred, y_sampled, paras = step_GP(X_train_masked, y_train_masked, X_test_jnp,
                                           noise_prior_dist=noise_prior_dist,
                                           lengthscale_prior_dist=lengthscale_prior_dist)

    # Find best predicted point (minimum since maximize=False)
    best_pred_idx = int(np.argmin(y_pred))
    best_pred_norm = points_3d[best_pred_idx]  # normalized coords
    best_pred_log10P = inverse_normalize(best_pred_norm[0], pressure_min, pressure_max)
    best_pred_T = inverse_normalize(best_pred_norm[1], T_min, T_max)
    best_pred_F = inverse_normalize(best_pred_norm[2], fluence_min, fluence_max)

    # Best measured (from the seed / measured dataset)
    meas_best_idx = int(np.argmin(y_train_masked))
    meas_best_norm = X_train_masked[meas_best_idx]
    meas_best_log10P = inverse_normalize(meas_best_norm[0], pressure_min, pressure_max)
    meas_best_T = inverse_normalize(meas_best_norm[1], T_min, T_max)
    meas_best_F = inverse_normalize(meas_best_norm[2], fluence_min, fluence_max)
    meas_best_y = float(y_train_masked[meas_best_idx])

    # Save checkpoint
    if save_checkpoints:
        ckpt_name = f'BO_ckpt_n{n}_k{k}.npz'
        save_data(
            ckpt_name,
            X_train_masked, y_train_masked, points_3d,
            x1=Pressure, x2=Temperature, x3=Fluence,
            y_pred=y_pred, y_sampled=y_sampled, acq=acq,
            next_point=None, running_best=meas_best_y, iteration=0
        )

    # Optional per-run plotting (commented out by default)
    if plot_each_run:
        plot_3d_projections(y_pred, Pressure, Temperature, Fluence, title=f'GP Mean n{n}_k{k}', X_train=X_train_masked, y_train=y_train_masked)

    # Append to results
    results.append({
        'n': n,
        'k': k,
        'alpha': alpha,
        'beta': beta,
        'gamma': gamma,
        'delta': delta,
        'best_pred_score': float(np.min(y_pred)),
        'best_pred_log10P': float(best_pred_log10P),
        'best_pred_pressure_Torr': 10**(float(best_pred_log10P)),
        'best_pred_temperature_C': float(best_pred_T),
        'best_pred_fluence_Jpcm2': float(best_pred_F),
        'meas_best_score': meas_best_y,
        'meas_best_log10P': float(meas_best_log10P),
        'meas_best_pressure_Torr': 10**(float(meas_best_log10P)),
        'meas_best_temperature_C': float(meas_best_T),
        'meas_best_fluence_Jpcm2': float(meas_best_F),
    })

# %%
# --- Save and summarize results ---
results_df = pd.DataFrame(results)
print('\nSummary:')
print(results_df)

# Save table to excel/csv
results_df.to_csv('best_points_by_weights.csv', index=False)
results_df.to_excel('best_points_by_weights.xlsx', index=False)
print('Saved best_points_by_weights.csv/.xlsx to current directory')

# Histogram of best predicted scores
plt.figure(figsize=(8,5))
plt.hist(results_df['best_pred_score'], bins=8, edgecolor='k')
plt.xlabel('Best Predicted Score')
plt.ylabel('Count')
plt.title('Histogram of Best Predicted Samples (over weight sets)')
plt.show()

# %%
# --- 3D Plotly of best predicted points (one marker per (n,k)) ---

hover_text = []
for r in results:
    txt = (f"n={r['n']}, k={r['k']}<br>score={r['best_pred_score']:.4f}" +
           f"<br>P={r['best_pred_pressure_Torr']:.2e} Torr<br>T={r['best_pred_temperature_C']:.0f} C<br>F={r['best_pred_fluence_Jpcm2']:.2f} J/cm^2")
    hover_text.append(txt)

fig = go.Figure(data=[
    go.Scatter3d(
        x=[r['best_pred_log10P'] for r in results],  # log10(P)
        y=[r['best_pred_temperature_C'] for r in results],
        z=[r['best_pred_fluence_Jpcm2'] for r in results],
        mode='markers+text',
        text=[f"n={r['n']},k={r['k']}" for r in results],
        hovertext=hover_text,
        marker=dict(size=6, color=[r['best_pred_score'] for r in results], colorscale='Viridis', colorbar=dict(title='Score'))
    )
])
fig.update_layout(
    scene=dict(
        xaxis_title='log10(Pressure) (Torr)',
        yaxis_title='Temperature (C)',
        zaxis_title='Fluence (J/cm^2)'
    ),
    title='Best Predicted Points for Different Weight Sets'
)
fig.show()

print('Done. Check the CSV/XLSX for the full table of results.')
# Out:
# 3D parameter space has size: (9758, 3)
# Pressure points (log10): (41,)
# Temperature points: (17,)
# Fluence points: (14,)
# Example back-transformed Pressure (Torr): [3.00000000e-08 3.77677624e-08 4.75467958e-08]
# If running in Colab: use files.upload() to upload Excel file.
# Or set file_path directly in the script.
# Using Excel file: /content/LaVO3_PLD_Parameters_working_pressure_fixed_cleaned_up_no_10nm_no_LaVO4_to_B38.xlsx
#
# ============================================================
# Running weights: n=1, k=1 (m=l=1)
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 617.61it/s, init loss: 37.7699, avg. loss [951-1000]: 29.2286]
# Inferred GP parameters
# k_length         [0.2683 0.8027 1.3764]
# k_scale          0.9189
# noise            0.11230000000000001
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=1, k=2 (m=l=1)
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 611.18it/s, init loss: 42.0440, avg. loss [951-1000]: 36.8796]
# Inferred GP parameters
# k_length         [0.2509 0.7346 1.0282]
# k_scale          1.4480000000000002
# noise            0.162
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=1, k=3 (m=l=1)
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 621.11it/s, init loss: 47.6279, avg. loss [951-1000]: 43.3951]
# Inferred GP parameters
# k_length         [0.2312 0.6528 0.6814]
# k_scale          2.4194
# noise            0.1433
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=2, k=1 (m=l=1)
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 548.18it/s, init loss: 40.1366, avg. loss [951-1000]: 33.6005]
# Inferred GP parameters
# k_length         [0.3244 0.8178 1.3042]
# k_scale          1.2639
# noise            0.1567
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=2, k=2 (m=l=1)
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:02<00:00, 454.73it/s, init loss: 44.5165, avg. loss [951-1000]: 39.8447]
# Inferred GP parameters
# k_length         [0.2981 0.7654 1.1813]
# k_scale          1.7757
# noise            0.216
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=2, k=3 (m=l=1)
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 590.04it/s, init loss: 50.2063, avg. loss [951-1000]: 45.6932]
# Inferred GP parameters
# k_length         [0.2653 0.6824 0.8013]
# k_scale          2.7445
# noise            0.21150000000000002
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=3, k=1 (m=l=1)
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:02<00:00, 376.49it/s, init loss: 43.8915, avg. loss [951-1000]: 38.5832]
# Inferred GP parameters
# k_length         [0.3691 0.7992 1.2284]
# k_scale          1.7094
# noise            0.2207
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=3, k=2 (m=l=1)
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 512.40it/s, init loss: 48.3773, avg. loss [951-1000]: 43.4987]
# Inferred GP parameters
# k_length         [0.3398 0.7644 1.1902]
# k_scale          2.245
# noise            0.2783
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=3, k=3 (m=l=1)
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 564.63it/s, init loss: 54.1730, avg. loss [951-1000]: 48.4909]
# Inferred GP parameters
# k_length         [0.3131 0.7268 1.0459]
# k_scale          2.9685
# noise            0.3385
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# Summary:
#    n  k    alpha    beta   gamma   delta  best_pred_score  best_pred_log10P  \
# 0  1  1   6.0606  0.0876  4.3879  0.0338         0.402957         -4.622879
# 1  1  2   6.0606  0.0876  4.3879  0.0676         0.585501         -4.322879
# 2  1  3   6.0606  0.0876  4.3879  0.1014         0.553478         -5.322879
# 3  2  1  12.1212  0.0876  4.3879  0.0338         0.440171         -5.922879
# 4  2  2  12.1212  0.0876  4.3879  0.0676         0.630073         -5.922879
# 5  2  3  12.1212  0.0876  4.3879  0.1014         0.746237         -5.522879
# 6  3  1  18.1818  0.0876  4.3879  0.0338         0.482550         -5.922879
# 7  3  2  18.1818  0.0876  4.3879  0.0676         0.664264         -5.922879
# 8  3  3  18.1818  0.0876  4.3879  0.1014         0.847592         -5.922879
#
#    best_pred_pressure_Torr  best_pred_temperature_C  best_pred_fluence_Jpcm2  \
# 0                 0.000024               500.000000                 0.800000
# 1                 0.000048               500.000000                 2.099999
# 2                 0.000005               819.999993                 1.400000
# 3                 0.000001               819.999993                 0.800000
# 4                 0.000001               819.999993                 0.800000
# 5                 0.000003               819.999993                 1.300000
# 6                 0.000001               819.999993                 0.800000
# 7                 0.000001               819.999993                 0.800000
# 8                 0.000001               819.999993                 0.800000
#
#    meas_best_score  meas_best_log10P  meas_best_pressure_Torr  \
# 0         0.361726         -4.657577                 0.000022
# 1         0.554386         -4.657577                 0.000022
# 2         0.713022         -4.013228                 0.000097
# 3         0.367787         -4.657577                 0.000022
# 4         0.560447         -4.657577                 0.000022
# 5         0.725143         -4.013228                 0.000097
# 6         0.373847         -4.657577                 0.000022
# 7         0.566507         -4.657577                 0.000022
# 8         0.737264         -4.013228                 0.000097
#
#    meas_best_temperature_C  meas_best_fluence_Jpcm2
# 0                    700.0                     1.00
# 1                    700.0                     1.00
# 2                    525.0                     0.83
# 3                    700.0                     1.00
# 4                    700.0                     1.00
# 5                    525.0                     0.83
# 6                    700.0                     1.00
# 7                    700.0                     1.00
# 8                    525.0                     0.83
# Saved best_points_by_weights.csv/.xlsx to current directory
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="0e36623c-0560-446c-afc2-0577a2f2f8c7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0e36623c-0560-446c-afc2-0577a2f2f8c7")) {                    Plotly.newPlot(                        "0e36623c-0560-446c-afc2-0577a2f2f8c7",                        [{"hovertext":["n=1, k=1\u003cbr\u003escore=0.4030\u003cbr\u003eP=2.38e-05 Torr\u003cbr\u003eT=500 C\u003cbr\u003eF=0.80 J\u002fcm^2","n=1, k=2\u003cbr\u003escore=0.5855\u003cbr\u003eP=4.75e-05 Torr\u003cbr\u003eT=500 C\u003cbr\u003eF=2.10 J\u002fcm^2","n=1, k=3\u003cbr\u003escore=0.5535\u003cbr\u003eP=4.75e-06 Torr\u003cbr\u003eT=820 C\u003cbr\u003eF=1.40 J\u002fcm^2","n=2, k=1\u003cbr\u003escore=0.4402\u003cbr\u003eP=1.19e-06 Torr\u003cbr\u003eT=820 C\u003cbr\u003eF=0.80 J\u002fcm^2","n=2, k=2\u003cbr\u003escore=0.6301\u003cbr\u003eP=1.19e-06 Torr\u003cbr\u003eT=820 C\u003cbr\u003eF=0.80 J\u002fcm^2","n=2, k=3\u003cbr\u003escore=0.7462\u003cbr\u003eP=3.00e-06 Torr\u003cbr\u003eT=820 C\u003cbr\u003eF=1.30 J\u002fcm^2","n=3, k=1\u003cbr\u003escore=0.4825\u003cbr\u003eP=1.19e-06 Torr\u003cbr\u003eT=820 C\u003cbr\u003eF=0.80 J\u002fcm^2","n=3, k=2\u003cbr\u003escore=0.6643\u003cbr\u003eP=1.19e-06 Torr\u003cbr\u003eT=820 C\u003cbr\u003eF=0.80 J\u002fcm^2","n=3, k=3\u003cbr\u003escore=0.8476\u003cbr\u003eP=1.19e-06 Torr\u003cbr\u003eT=820 C\u003cbr\u003eF=0.80 J\u002fcm^2"],"marker":{"color":[0.4029565490299792,0.5855013185643523,0.5534775047776593,0.44017102818465337,0.6300727971794797,0.746236754348266,0.4825499513338177,0.6642635017661339,0.8475916976463714],"colorbar":{"title":{"text":"Score"}},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"size":6},"mode":"markers+text","text":["n=1,k=1","n=1,k=2","n=1,k=3","n=2,k=1","n=2,k=2","n=2,k=3","n=3,k=1","n=3,k=2","n=3,k=3"],"x":[-4.622878745280337,-4.322878745280337,-5.322878745280337,-5.922878745280338,-5.922878745280338,-5.522878745280337,-5.922878745280338,-5.922878745280338,-5.922878745280338],"y":[500.0,500.0,819.9999925494194,819.9999925494194,819.9999925494194,819.9999925494194,819.9999925494194,819.9999925494194,819.9999925494194],"z":[0.8,2.099999463558197,1.3999998390674593,0.8,0.8,1.2999998450279238,0.8,0.8,0.8],"type":"scatter3d"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[ ...
# Done. Check the CSV/XLSX for the full table of results.

# %% [markdown]
# # Starting from scratch gpbo weighting loop: looping through all 4 metrics (n, l, m, k)

# %%
# Script that:
# - Loads Excel data
# - Builds the 3D grid (Pressure (log10), Temperature, Fluence)
# - Loops over n,k in {1,2,3} (m=l=1), computes y_train for each weight set
# - Retrains the gpax viGP for each (n,k) from scratch
# - Predicts across the full 3D grid, finds the best predicted point and best measured point
# - Saves a results table, histogram, and an interactive Plotly 3D scatter of best points
#
# Notes:
# - Run the cells in order in Colab. If you want to upload a file instead of setting file_path,
#   use the files.upload() flow provided.
# - This script intentionally does NOT plot the full GP maps for every (n,k) to save time.
#   You can enable per-run plotting by setting `plot_each_run = True`.
# - Speed tips: reduce grid resolution (larger step sizes) or run fewer HMC samples (if you
#   expose fit arguments). Avoid running multiple GP fits simultaneously (JAX + multiprocessing
#   can deadlock).

# %%
# Install (uncomment in Colab if needed)
# NOTE: gpax may be a private package in your environment. If gpax is installed locally, skip install.
# !pip install gpax plotly openpyxl numpyro

# %%
# Imports and global settings
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from itertools import product
from pathlib import Path

import jax
import jax.numpy as jnp
import gpax

# Enable 64-bit (same as your previous cell)
gpax.utils.enable_x64()

# Plotly for interactive 3D
import plotly.graph_objects as go

# Colab file upload helper
try:
    from google.colab import files
except Exception:
    files = None

# %%
# --- Helper functions (normalize / inverse normalize / save/load) ---

def normalize(data, min_val, max_val):
    return (data - min_val) / (max_val - min_val)


def inverse_normalize(norm_data, min_val, max_val):
    return norm_data * (max_val - min_val) + min_val


def save_data(
    file_name,
    X_train, y_train,
    X_test,
    x1, x2, x3,
    y_pred, y_sampled,
    acq, next_point,
    running_best,
    iteration
):
    np.savez(
        file_name,
        X_train=X_train,
        y_train=y_train,
        X_test=X_test,
        x1=x1,
        x2=x2,
        x3=x3,
        y_pred=y_pred,
        y_sampled=y_sampled,
        acq=acq,
        next_point=next_point,
        running_best=running_best,
        iteration=iteration
    )


def load_data(file_name):
    ds = np.load(file_name, allow_pickle=True)
    return (
        ds['X_train'],
        ds['y_train'],
        ds['X_test'],
        ds['x1'],
        ds['x2'],
        ds['x3'],
        ds['y_pred'],
        ds['y_sampled'],
        ds['acq'],
        ds['next_point'],
        ds['running_best'],
        ds['iteration']
    )


def update_datapoints(X_new, y_new, X_train, y_train):
    X_train = jnp.append(X_train, X_new, axis=0)
    y_train = jnp.append(y_train, y_new, axis=0)
    return X_train, y_train

# Reuse plotting routine (matplotlib projections), pretty much unchanged.
# Note: this function references globals pressure_min, pressure_max, T_min, T_max, fluence_min, fluence_max
# which will be set after the grid build cell below.

def plot_3d_projections(
    field_flat,
    P_array,
    T_array,
    F_array,
    title: str,
    X_train: np.ndarray = None,
    y_train: np.ndarray = None,
    deg_sgn: str = '°'
):
    field = np.asarray(field_flat)
    nP, nT, nF = len(P_array), len(T_array), len(F_array)
    if field.size != nP * nT * nF:
        raise ValueError(f"field length {field.size} != {nP}*{nT}*{nF}")

    field3d = field.reshape(nP, nT, nF)
    proj_PT = field3d.mean(axis=2)
    proj_PF = field3d.mean(axis=1)
    proj_TF = field3d.mean(axis=0)

    fig, axs = plt.subplots(1, 3, figsize=(18, 6), dpi=200, constrained_layout=True)
    for ax in axs:
        ax.tick_params(axis='both', labelsize=12)
    font_title = 20
    font_label = 18
    font_tick = 14

    im0 = axs[0].pcolormesh(P_array, T_array, proj_PT.T, shading='auto', cmap='nipy_spectral')
    axs[0].set_xlabel('log$_{10}$ O$_2$ Partial Pressure (log$_{10}$ Torr)', fontsize=font_label)
    axs[0].set_ylabel(f'Deposition Temperature ({deg_sgn}C)', fontsize=font_label)
    axs[0].set_title(f'{title} → T vs P', fontsize=font_title)
    fig.colorbar(im0, ax=axs[0], orientation='vertical')

    im1 = axs[1].pcolormesh(P_array, F_array, proj_PF.T, shading='auto', cmap='nipy_spectral')
    axs[1].set_xlabel('log$_{10}$ O$_2$ Partial Pressure (log$_{10}$ Torr)', fontsize=font_label)
    axs[1].set_ylabel('Fluence (J/cm$^2$)', fontsize=font_label)
    axs[1].set_title(f'{title} → F vs P', fontsize=font_title)
    fig.colorbar(im1, ax=axs[1], orientation='vertical')

    im2 = axs[2].pcolormesh(T_array, F_array, proj_TF.T, shading='auto', cmap='nipy_spectral')
    axs[2].set_xlabel(f'Deposition Temperature ({deg_sgn}C)', fontsize=font_label)
    axs[2].set_ylabel('Fluence (J/cm$^2$)', fontsize=font_label)
    axs[2].set_title(f'{title} → F vs T', fontsize=font_title)
    fig.colorbar(im2, ax=axs[2], orientation='vertical')

    if X_train is not None and y_train is not None:
        P_train = inverse_normalize(X_train[:,0], pressure_min, pressure_max)
        T_train = inverse_normalize(X_train[:,1], T_min, T_max)
        F_train = inverse_normalize(X_train[:,2], fluence_min, fluence_max)
        y_vals  = y_train.flatten()

        scatter_kwargs = dict(c=y_vals, cmap='Reds', edgecolor='k', s=200, alpha=0.8)

        sc0 = axs[0].scatter(P_train, T_train, **scatter_kwargs)
        sc1 = axs[1].scatter(P_train, F_train, **scatter_kwargs)
        sc2 = axs[2].scatter(T_train, F_train, **scatter_kwargs)

        from mpl_toolkits.axes_grid1.inset_locator import inset_axes
        cbar_ax = inset_axes(
            axs[2],
            width="60%",
            height="5%",
            loc='upper left',
            bbox_to_anchor=(0.55, 0.3, 1, 1),
            bbox_transform=axs[2].transAxes,
            borderpad=0,
        )
        cbar = fig.colorbar(sc0, cax=cbar_ax, orientation='horizontal')
        cbar.set_label('Sample\nScores', fontsize=font_label)
        cbar.ax.tick_params(labelsize=font_tick)

    fig.suptitle(
    f"{title}: Min-Max Scaling\n"
    r"$y_{\mathrm{train}} = \alpha \cdot |c - 3.945| + \beta \cdot R_{RMS} + \gamma \cdot FWHM + \delta \cdot LaVO_{4}$" + "\n" +
    f"[α = {alpha}, β = {beta}, γ = {gamma}, δ = {delta}]",
    fontsize=16,
    fontweight='bold',
    y=1.17
    )
    plt.show()

# %%
# --- Build the 3D grid (pressures are represented as log10(pressure)) ---
# Pressure bounds (same as your provided code)
start, stop = 3e-8, 3e-4
num_points_per_decade = 10
total_decades = int(np.log10(stop / start))
total_points = total_decades * num_points_per_decade + 1

# Pressure array stored as log10(pressure)
Pressure = np.log10(np.geomspace(start, stop, num=total_points))
pressure_min, pressure_max = Pressure.min(), Pressure.max()

# Temperature
T_min, T_max, T_stepsize = 500, 835, 20
Temperature = np.arange(T_min, T_max, T_stepsize, dtype=np.float32)

# Fluence
fluence_min, fluence_max, fluence_stepsize = 0.8, 2.2, 0.1
Fluence = np.arange(fluence_min, fluence_max, fluence_stepsize, dtype=np.float32)

# Normalized grids
P_norm = normalize(Pressure, pressure_min, pressure_max)
T_norm = normalize(Temperature, T_min, T_max)
F_norm = normalize(Fluence, fluence_min, fluence_max)

# Meshgrid in normalized space
Pg, Tg, Fg = np.meshgrid(P_norm, T_norm, F_norm, indexing='ij')
P_flat = Pg.reshape(-1, 1)
T_flat = Tg.reshape(-1, 1)
F_flat = Fg.reshape(-1, 1)
points_3d = np.hstack((P_flat, T_flat, F_flat))

print('3D parameter space has size:', points_3d.shape)
print('Pressure points (log10):', Pressure.shape)
print('Temperature points:', Temperature.shape)
print('Fluence points:', Fluence.shape)
print('Example back-transformed Pressure (Torr):', 10**(Pressure[:3]))

# Convert X_test to jax array once for faster device transfer
X_test_jnp = jnp.asarray(points_3d)

# %%
# --- GP step function (wraps gpax.viGP) ---
import numpyro
from numpyro import distributions
from jax import random

# Optionally define priors here (you can tune these or set to None)
lengthscale_prior_dist = None
noise_prior_dist = None


def step_GP(X_measured, y_measured, X_unmeasured,
            noise_prior_dist=None,
            lengthscale_prior_dist=None):
    rng_key1, rng_key2 = gpax.utils.get_keys()

    # Convert to jax arrays
    X_measured_j = jnp.asarray(X_measured)
    y_measured_j = jnp.asarray(y_measured).ravel()

    gp_model = gpax.viGP(
        input_dim=3,
        kernel='Matern',
        noise_prior_dist=noise_prior_dist,
        lengthscale_prior_dist=lengthscale_prior_dist
    )

    print('Training Model (this may take some time).')
    # You can pass additional kwargs into .fit if gpax supports them (e.g., fewer HMC samples)
    gp_model.fit(rng_key1, X_measured_j, y_measured_j, jitter=1e-2)

    print('Getting Model Predictions.')
    y_pred, y_sampled = gp_model.predict_in_batches(
        rng_key2,
        X_unmeasured,
        noiseless=False,
        jitter=1e-2
    )

    print('Calculating acquisition.')
    acquisition = gpax.acquisition.EI(
        rng_key2,
        gp_model,
        X_unmeasured,
        maximize=False,
        recent_points=X_measured_j,
        noiseless=False,
        jitter=1e-2,
        penalty='delta'
    )

    print('Getting parameter samples.')
    paras = gp_model.get_samples()

    # Convert outputs back to numpy for convenience
    return np.asarray(acquisition), np.asarray(y_pred), np.asarray(y_sampled), paras

# %%
# --- Load Excel / Build seed points ---

# Option A: Set path directly (if file already uploaded to /content)
file_path = '/content/LaVO3_PLD_Parameters_working_pressure_fixed_cleaned_up_no_10nm_no_LaVO4_to_B38.xlsx'
df = pd.read_excel(file_path)

# Option B: Use files.upload() in Colab
if files is not None:
    print('If running in Colab: use files.upload() to upload your Excel file.\nOr set file_path directly in the script.')

# We'll try to pick up a file in /content if user dropped one there, otherwise use upload
content_files = list(Path('/content').glob('*.xlsx')) + list(Path('.').glob('*.xlsx'))
if len(content_files) == 0:
    if files is not None:
        uploaded = files.upload()
        # take the first uploaded file
        first = next(iter(uploaded.keys()))
        file_path = f'/content/{first}'
    else:
        raise FileNotFoundError('No .xlsx files found in working directory and files.upload() is unavailable.')
else:
    file_path = str(content_files[0])

print('Using Excel file:', file_path)

# Read sheet (adjust sheet_name if necessary)
df = pd.read_excel(file_path, sheet_name=0)

# Extract columns (fall back to alternative names if necessary)
# Use the exact column names; if any KeyError occurs, inspect df.columns

colmap = {
    'Sample ID': 'Sample ID',
    'Date (YYMMDD)': 'Date (YYMMDD)',
    'Fluence': 'Fluence (J/cm2)',
    'O2 Pressure': 'O2 Pressure (Torr)',
    'Working pressure': 'Working pressure (Torr)',
}

# Try to access the columns listed earlier; adapt if column names differ
try:
    fluence = df['Fluence (J/cm2)'].values.astype(float)
    o2_pressure = df['O2 Pressure (Torr)'].values.astype(float)
    substrate_temp = df['Substrate Temp. (C) (based on average of temperature measured near substrate)'].values.astype(float)
    roughness = df['Roughness (nm) (standard deviation of height: 3x3 um, 2 Hz, 512 sam/l, B25 sub only = 0.147 )'].values.astype(float)
    c_lattice_parameter = df['C Lattice Parameter from Fringes (Å) (or 2Tw  peak position*)'].values.astype(float)
    fwhm_rocking_curve = df['FWHM (deg) (Gaussian fitting of rocking curve: B25: sub only, 1 twin=0.0050 )'].values.astype(float)
    integrated_intensity = df['Integrated LaVO4 Intensity: 48-51, normalized, x10^6 [B25 sub only= 4.7 (250520)]'].values.astype(float)
except Exception as e:
    print('Column name mismatch: please inspect df.columns')
    print(df.columns)
    raise e

# Build raw seed points array (physical values)
seed_points_raw = np.column_stack((o2_pressure, substrate_temp, fluence))

# Normalize seed points into [0,1]
seed_points = np.zeros_like(seed_points_raw, dtype=np.float32)
seed_points[:, 0] = normalize(np.log10(seed_points_raw[:, 0]), pressure_min, pressure_max)
seed_points[:, 1] = normalize(seed_points_raw[:, 1], T_min, T_max)
seed_points[:, 2] = normalize(seed_points_raw[:, 2], fluence_min, fluence_max)

# initial X_train (normalized) and placeholders
X_train_initial = seed_points

# NOTE: y_train will be recalculated inside the loop for each (n,k)

# %%
# --- Main loop over weight combinations (n,m,l,k) ---
results = []

# Control flags
plot_each_run = False   # set True if you want to plot the GP results for each (n,k)
save_checkpoints = True # save a .npz checkpoint per run

# --- Loop over n, m, l, k ---
for n, m, l, k in product([0,1,2,3], repeat=4):
    print('\n' + '='*60)
    print(f'Running weights: n={n}, m={m}, l={l}, k={k}')
    alpha = 6.0606 * n
    beta = 0.0876 * m
    gamma = 4.3879 * l
    delta = 0.0338 * k

    lattice_parameter_mismatch = np.abs(c_lattice_parameter - LVO_c_lit)
    y_1 = alpha * lattice_parameter_mismatch
    y_2 = beta * roughness
    y_3 = gamma * fwhm_rocking_curve
    y_4 = delta * integrated_intensity
    y_train_full = (y_1 + y_2 + y_3 + y_4).astype(float)

    mask_good = np.isfinite(y_train_full)
    if not np.all(mask_good):
        print(f'Warning: {np.count_nonzero(~mask_good)} bad rows in y_train; dropping them.')

    X_train_masked = X_train_initial[mask_good]
    y_train_masked = y_train_full[mask_good]

    print(f"Number of samples used to train GP surrogate model for weights n={n}, m={m}, l={l}, k={k}: {X_train_masked.shape[0]}")


    acq, y_pred, y_sampled, paras = step_GP(
        X_train_masked, y_train_masked, X_test_jnp,
        noise_prior_dist=noise_prior_dist,
        lengthscale_prior_dist=lengthscale_prior_dist
    )

    best_pred_idx = int(np.argmin(y_pred))
    best_pred_norm = points_3d[best_pred_idx]
    best_pred_log10P = inverse_normalize(best_pred_norm[0], pressure_min, pressure_max)
    best_pred_T = inverse_normalize(best_pred_norm[1], T_min, T_max)
    best_pred_F = inverse_normalize(best_pred_norm[2], fluence_min, fluence_max)

    meas_best_idx = int(np.argmin(y_train_masked))
    meas_best_norm = X_train_masked[meas_best_idx]
    meas_best_log10P = inverse_normalize(meas_best_norm[0], pressure_min, pressure_max)
    meas_best_T = inverse_normalize(meas_best_norm[1], T_min, T_max)
    meas_best_F = inverse_normalize(meas_best_norm[2], fluence_min, fluence_max)
    meas_best_y = float(y_train_masked[meas_best_idx])

    if save_checkpoints:
        ckpt_name = f'BO_ckpt_n{n}_m{m}_l{l}_k{k}.npz'
        save_data(
            ckpt_name,
            X_train_masked, y_train_masked, points_3d,
            x1=Pressure, x2=Temperature, x3=Fluence,
            y_pred=y_pred, y_sampled=y_sampled, acq=acq,
            next_point=None, running_best=meas_best_y, iteration=0
        )

    if plot_each_run:
        plot_3d_projections(
            y_pred, Pressure, Temperature, Fluence,
            title=f'GP Mean n{n}_m{m}_l{l}_k{k}',
            X_train=X_train_masked, y_train=y_train_masked
        )

    results.append({
        'n': n,
        'm': m,
        'l': l,
        'k': k,
        'alpha': alpha,
        'beta': beta,
        'gamma': gamma,
        'delta': delta,
        'best_pred_score': float(np.min(y_pred)),
        'best_pred_log10P': float(best_pred_log10P),
        'best_pred_pressure_Torr': 10**(float(best_pred_log10P)),
        'best_pred_temperature_C': float(best_pred_T),
        'best_pred_fluence_Jpcm2': float(best_pred_F),
        'meas_best_score': meas_best_y,
        'meas_best_log10P': float(meas_best_log10P),
        'meas_best_pressure_Torr': 10**(float(meas_best_log10P)),
        'meas_best_temperature_C': float(meas_best_T),
        'meas_best_fluence_Jpcm2': float(meas_best_F),
    })

# After loop: Convert to DataFrame and save as before
results_df = pd.DataFrame(results)
print('\nSummary:')
print(results_df)
results_df.to_csv('best_points_by_weights.csv', index=False)
results_df.to_excel('best_points_by_weights.xlsx', index=False)
print('Saved best_points_by_weights.csv/.xlsx to current directory')

# --- Histogram ---
# Number of bins per dimension
n_bins = 7

# Define bin edges for each parameter
pressure_bins = np.linspace(pressure_min, pressure_max, n_bins + 1)
temperature_bins = np.linspace(T_min, T_max, n_bins + 1)
fluence_bins = np.linspace(fluence_min, fluence_max, n_bins + 1)

bin_labels = []
bin_counts = []

best_P = np.array([r['best_pred_log10P'] for r in results])
best_T = np.array([r['best_pred_temperature_C'] for r in results])
best_F = np.array([r['best_pred_fluence_Jpcm2'] for r in results])

# Loop through bins and gather only bins with points
for i in range(n_bins):
    for j in range(n_bins):
        for k in range(n_bins):
            p_min, p_max = pressure_bins[i], pressure_bins[i + 1]
            t_min, t_max = temperature_bins[j], temperature_bins[j + 1]
            f_min, f_max = fluence_bins[k], fluence_bins[k + 1]

            inside_bin = (
                (best_P >= p_min) & (best_P < p_max) &
                (best_T >= t_min) & (best_T < t_max) &
                (best_F >= f_min) & (best_F < f_max)
            )
            count = np.sum(inside_bin)
            if count > 0:
                bin_counts.append(count)
                label = (
                    f"P: {10**p_min:.1e}-{10**p_max:.1e} Torr\n"
                    f"T: {t_min:.0f}-{t_max:.0f} C\n"
                    f"F: {f_min:.2f}-{f_max:.2f} J/cm²"
                )
                bin_labels.append(label)

# Plot only bins with points
plt.figure(figsize=(14, 6), dpi=200)
bars = plt.bar(range(len(bin_counts)), bin_counts, edgecolor='k')
plt.xticks(range(len(bin_counts)), bin_labels, rotation=75, fontsize=9)
plt.ylabel('Count of Best Predicted Points')
plt.title(f'Histogram of Best Predicted Points Binned by 3D Parameter Space ({n_bins} bins per dimension)')

# Add count labels above each bar
for bar in bars:
    height = bar.get_height()
    plt.text(
        bar.get_x() + bar.get_width() / 2,  # x-position: center of the bar
        height,                             # y-position: top of the bar
        f'{int(height)}',                   # label text
        ha='center', va='bottom', fontsize=10
    )

plt.tight_layout()
plt.show()



# Updated Plotly 3D scatter for best predicted points, now showing (n,m,l,k)
hover_text = []
for r in results:
    txt = (f"n={r['n']}, m={r['m']}, l={r['l']}, k={r['k']}<br>"
           f"score={r['best_pred_score']:.4f}<br>"
           f"P={r['best_pred_pressure_Torr']:.2e} Torr<br>"
           f"T={r['best_pred_temperature_C']:.0f} C<br>"
           f"F={r['best_pred_fluence_Jpcm2']:.2f} J/cm^2")
    hover_text.append(txt)

fig = go.Figure(data=[
    go.Scatter3d(
        x=[r['best_pred_log10P'] for r in results],  # log10(P)
        y=[r['best_pred_temperature_C'] for r in results],
        z=[r['best_pred_fluence_Jpcm2'] for r in results],
        mode='markers',
        hovertext=hover_text,
        marker=dict(
            size=10,
            color=[r['best_pred_score'] for r in results],
            colorscale='Viridis',
            colorbar=dict(title='Score')
        )
    )
])
fig.update_layout(
    scene=dict(
        xaxis_title='log10(Pressure) (Torr)',
        yaxis_title='Temperature (C)',
        zaxis_title='Fluence (J/cm^2)'
    ),
    title='Best Predicted Points for Different Weight Sets (n,m,l,k)',
    width=1100,   # wider plot
    height=700    # taller plot
)
fig.show()

print('Done. Check the CSV/XLSX for the full table of results.')
# Out:
# 3D parameter space has size: (9758, 3)
# Pressure points (log10): (41,)
# Temperature points: (17,)
# Fluence points: (14,)
# Example back-transformed Pressure (Torr): [3.00000000e-08 3.77677624e-08 4.75467958e-08]
# If running in Colab: use files.upload() to upload your Excel file.
# Or set file_path directly in the script.
# Using Excel file: /content/LaVO3_PLD_Parameters_working_pressure_fixed_cleaned_up_no_10nm_no_LaVO4_to_B38.xlsx
#
# ============================================================
# Running weights: n=0, m=0, l=0, k=0
# Number of samples used to train GP surrogate model for weights n=0, m=0, l=0, k=0: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:02<00:00, 341.10it/s, init loss: 31.0194, avg. loss [951-1000]: -10.6753]
# Inferred GP parameters
# k_length         [1.0385 1.1118 0.9615]
# k_scale          0.041800000000000004
# noise            0.014700000000000001
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=0, m=0, l=0, k=1
# Number of samples used to train GP surrogate model for weights n=0, m=0, l=0, k=1: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 583.17it/s, init loss: 31.6743, avg. loss [951-1000]: 3.8180]
# Inferred GP parameters
# k_length         [0.4964 0.9526 1.0733]
# k_scale          0.1155
# noise            0.0332
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=0, m=0, l=0, k=2
# Number of samples used to train GP surrogate model for weights n=0, m=0, l=0, k=2: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 556.45it/s, init loss: 33.6391, avg. loss [951-1000]: 19.1025]
# Inferred GP parameters
# k_length         [0.3128 0.8064 0.8397]
# k_scale          0.35500000000000004
# noise            0.08070000000000001
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=0, m=0, l=0, k=3
# Number of samples used to train GP surrogate model for weights n=0, m=0, l=0, k=3: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 593.59it/s, init loss: 36.9137, avg. loss [951-1000]: 29.7141]
# Inferred GP parameters
# k_length         [0.2496 0.7187 0.6177]
# k_scale          0.8278000000000001
# noise            0.1106
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=0, m=0, l=1, k=0
# Number of samples used to train GP surrogate model for weights n=0, m=0, l=1, k=0: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 599.57it/s, init loss: 32.1399, avg. loss [951-1000]: 8.8327]
# Inferred GP parameters
# k_length         [0.3553 1.1868 0.9673]
# k_scale          0.1499
# noise            0.0456
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=0, m=0, l=1, k=1
# Number of samples used to train GP surrogate model for weights n=0, m=0, l=1, k=1: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 584.21it/s, init loss: 34.0927, avg. loss [951-1000]: 21.0412]
# Inferred GP parameters
# k_length         [0.3156 0.9396 0.7892]
# k_scale          0.3755
# noise            0.0971
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=0, m=0, l=1, k=2
# Number of samples used to train GP surrogate model for weights n=0, m=0, l=1, k=2: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 588.31it/s, init loss: 37.3553, avg. loss [951-1000]: 30.7807]
# Inferred GP parameters
# k_length         [0.2601 0.7542 0.5441]
# k_scale          0.8619
# noise            0.1241
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=0, m=0, l=1, k=3
# Number of samples used to train GP surrogate model for weights n=0, m=0, l=1, k=3: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:02<00:00, 426.70it/s, init loss: 41.9278, avg. loss [951-1000]: 38.4878]
# Inferred GP parameters
# k_length         [0.2399 0.6718 0.4735]
# k_scale          1.6075000000000002
# noise            0.1213
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=0, m=0, l=2, k=0
# Number of samples used to train GP surrogate model for weights n=0, m=0, l=2, k=0: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 591.71it/s, init loss: 35.5012, avg. loss [951-1000]: 25.7776]
# Inferred GP parameters
# k_length         [0.2728 0.9853 0.7065]
# k_scale          0.44530000000000003
# noise            0.136
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=0, m=0, l=2, k=1
# Number of samples used to train GP surrogate model for weights n=0, m=0, l=2, k=1: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:02<00:00, 367.14it/s, init loss: 38.7519, avg. loss [951-1000]: 33.5531]
# Inferred GP parameters
# k_length         [0.2519 0.7837 0.4761]
# k_scale          0.9543
# noise            0.1506
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=0, m=0, l=2, k=2
# Number of samples used to train GP surrogate model for weights n=0, m=0, l=2, k=2: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 594.10it/s, init loss: 43.3124, avg. loss [951-1000]: 40.2575]
# Inferred GP parameters
# k_length         [0.2362 0.6876 0.4083]
# k_scale          1.7555
# noise            0.12710000000000002
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=0, m=0, l=2, k=3
# Number of samples used to train GP surrogate model for weights n=0, m=0, l=2, k=3: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 604.95it/s, init loss: 49.1828, avg. loss [951-1000]: 46.1966]
# Inferred GP parameters
# k_length         [0.2298 0.6521 0.4097]
# k_scale          2.5846
# noise            0.1529
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=0, m=0, l=3, k=0
# Number of samples used to train GP surrogate model for weights n=0, m=0, l=3, k=0: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 593.60it/s, init loss: 41.1034, avg. loss [951-1000]: 37.3160]
# Inferred GP parameters
# k_length         [0.2271 0.7891 0.4507]
# k_scale          1.0887
# noise            0.1925
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=0, m=0, l=3, k=1
# Number of samples used to train GP surrogate model for weights n=0, m=0, l=3, k=1: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 599.93it/s, init loss: 45.6520, avg. loss [951-1000]: 42.8976]
# Inferred GP parameters
# k_length         [0.2151 0.6943 0.3793]
# k_scale          1.9378000000000002
# noise            0.1449
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=0, m=0, l=3, k=2
# Number of samples used to train GP surrogate model for weights n=0, m=0, l=3, k=2: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 603.95it/s, init loss: 51.5104, avg. loss [951-1000]: 48.0688]
# Inferred GP parameters
# k_length         [0.2154 0.6604 0.3741]
# k_scale          2.8094
# noise            0.1562
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=0, m=0, l=3, k=3
# Number of samples used to train GP surrogate model for weights n=0, m=0, l=3, k=3: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 589.64it/s, init loss: 58.6787, avg. loss [951-1000]: 52.9033]
# Inferred GP parameters
# k_length         [0.2203 0.6501 0.3873]
# k_scale          3.6441000000000003
# noise            0.23700000000000002
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=0, m=1, l=0, k=0
# Number of samples used to train GP surrogate model for weights n=0, m=1, l=0, k=0: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:02<00:00, 400.26it/s, init loss: 31.7289, avg. loss [951-1000]: 2.5162]
# Inferred GP parameters
# k_length         [0.2815 0.7375 1.3172]
# k_scale          0.1076
# noise            0.0269
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=0, m=1, l=0, k=1
# Number of samples used to train GP surrogate model for weights n=0, m=1, l=0, k=1: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:06<00:00, 158.02it/s, init loss: 33.2894, avg. loss [951-1000]: 12.9554]
# Inferred GP parameters
# k_length         [0.2297 0.7286 1.8586]
# k_scale          0.32270000000000004
# noise            0.036500000000000005
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=0, m=1, l=0, k=2
# Number of samples used to train GP surrogate model for weights n=0, m=1, l=0, k=2: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 569.43it/s, init loss: 36.1598, avg. loss [951-1000]: 24.5783]
# Inferred GP parameters
# k_length         [0.2181 0.6997 1.3434]
# k_scale          0.6604
# noise            0.0711
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=0, m=1, l=0, k=3
# Number of samples used to train GP surrogate model for weights n=0, m=1, l=0, k=3: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 587.63it/s, init loss: 40.3400, avg. loss [951-1000]: 33.8823]
# Inferred GP parameters
# k_length         [0.2136 0.6698 0.8916]
# k_scale          1.1865
# noise            0.1119
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=0, m=1, l=1, k=0
# Number of samples used to train GP surrogate model for weights n=0, m=1, l=1, k=0: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:02<00:00, 340.71it/s, init loss: 33.9330, avg. loss [951-1000]: 16.7871]
# Inferred GP parameters
# k_length         [0.2324 0.8288 1.5494]
# k_scale          0.38270000000000004
# noise            0.0516
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=0, m=1, l=1, k=1
# Number of samples used to train GP surrogate model for weights n=0, m=1, l=1, k=1: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 575.88it/s, init loss: 36.7914, avg. loss [951-1000]: 26.6833]
# Inferred GP parameters
# k_length         [0.2224 0.7452 1.2233]
# k_scale          0.7110000000000001
# noise            0.0906
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=0, m=1, l=1, k=2
# Number of samples used to train GP surrogate model for weights n=0, m=1, l=1, k=2: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 532.67it/s, init loss: 40.9596, avg. loss [951-1000]: 35.1384]
# Inferred GP parameters
# k_length         [0.2138 0.6831 0.7902]
# k_scale          1.2618
# noise            0.12140000000000001
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=0, m=1, l=1, k=3
# Number of samples used to train GP surrogate model for weights n=0, m=1, l=1, k=3: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 591.02it/s, init loss: 46.4377, avg. loss [951-1000]: 42.1181]
# Inferred GP parameters
# k_length         [0.21   0.6446 0.6375]
# k_scale          2.025
# noise            0.14170000000000002
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=0, m=1, l=2, k=0
# Number of samples used to train GP surrogate model for weights n=0, m=1, l=2, k=0: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 567.36it/s, init loss: 38.3780, avg. loss [951-1000]: 30.5988]
# Inferred GP parameters
# k_length         [0.2125 0.7848 1.0497]
# k_scale          0.788
# noise            0.1316
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=0, m=1, l=2, k=1
# Number of samples used to train GP surrogate model for weights n=0, m=1, l=2, k=1: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 586.88it/s, init loss: 42.5343, avg. loss [951-1000]: 37.6509]
# Inferred GP parameters
# k_length         [0.2009 0.6892 0.6919]
# k_scale          1.3674000000000002
# noise            0.1439
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=0, m=1, l=2, k=2
# Number of samples used to train GP surrogate model for weights n=0, m=1, l=2, k=2: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 586.15it/s, init loss: 48.0004, avg. loss [951-1000]: 43.8024]
# Inferred GP parameters
# k_length         [0.1963 0.6411 0.5664]
# k_scale          2.1847000000000003
# noise            0.14070000000000002
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=0, m=1, l=2, k=3
# Number of samples used to train GP surrogate model for weights n=0, m=1, l=2, k=3: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:02<00:00, 497.92it/s, init loss: 54.7764, avg. loss [951-1000]: 49.2600]
# Inferred GP parameters
# k_length         [0.1994 0.6227 0.5308]
# k_scale          3.0780000000000003
# noise            0.17270000000000002
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=0, m=1, l=3, k=0
# Number of samples used to train GP surrogate model for weights n=0, m=1, l=3, k=0: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 602.45it/s, init loss: 45.0639, avg. loss [951-1000]: 40.7986]
# Inferred GP parameters
# k_length         [0.1572 0.6444 0.5704]
# k_scale          1.6279000000000001
# noise            0.1169
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=0, m=1, l=3, k=1
# Number of samples used to train GP surrogate model for weights n=0, m=1, l=3, k=1: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:02<00:00, 366.71it/s, init loss: 50.5180, avg. loss [951-1000]: 46.0583]
# Inferred GP parameters
# k_length         [0.1674 0.627  0.512 ]
# k_scale          2.4104
# noise            0.1254
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=0, m=1, l=3, k=2
# Number of samples used to train GP surrogate model for weights n=0, m=1, l=3, k=2: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 596.53it/s, init loss: 57.2821, avg. loss [951-1000]: 50.9692]
# Inferred GP parameters
# k_length         [0.1842 0.6265 0.4973]
# k_scale          3.2318000000000002
# noise            0.1943
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=0, m=1, l=3, k=3
# Number of samples used to train GP surrogate model for weights n=0, m=1, l=3, k=3: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 588.31it/s, init loss: 65.3559, avg. loss [951-1000]: 55.7735]
# Inferred GP parameters
# k_length         [0.199  0.642  0.5175]
# k_scale          3.8821000000000003
# noise            0.37060000000000004
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=0, m=2, l=0, k=0
# Number of samples used to train GP surrogate model for weights n=0, m=2, l=0, k=0: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 576.99it/s, init loss: 33.8574, avg. loss [951-1000]: 14.5772]
# Inferred GP parameters
# k_length         [0.2076 0.6536 1.587 ]
# k_scale          0.34090000000000004
# noise            0.037700000000000004
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=0, m=2, l=0, k=1
# Number of samples used to train GP surrogate model for weights n=0, m=2, l=0, k=1: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 607.01it/s, init loss: 36.3235, avg. loss [951-1000]: 20.3384]
# Inferred GP parameters
# k_length         [0.195  0.6629 2.5093]
# k_scale          0.6409
# noise            0.0351
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=0, m=2, l=0, k=2
# Number of samples used to train GP surrogate model for weights n=0, m=2, l=0, k=2: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 553.97it/s, init loss: 40.0994, avg. loss [951-1000]: 29.3867]
# Inferred GP parameters
# k_length         [0.1891 0.6328 1.9596]
# k_scale          1.0243
# noise            0.0648
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=0, m=2, l=0, k=3
# Number of samples used to train GP surrogate model for weights n=0, m=2, l=0, k=3: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 590.33it/s, init loss: 45.1852, avg. loss [951-1000]: 37.6106]
# Inferred GP parameters
# k_length         [0.1906 0.6247 1.3484]
# k_scale          1.5628
# noise            0.1206
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=0, m=2, l=1, k=0
# Number of samples used to train GP surrogate model for weights n=0, m=2, l=1, k=0: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:02<00:00, 419.20it/s, init loss: 37.1452, avg. loss [951-1000]: 23.2657]
# Inferred GP parameters
# k_length         [0.167  0.6689 2.2878]
# k_scale          0.7098
# noise            0.041
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=0, m=2, l=1, k=1
# Number of samples used to train GP surrogate model for weights n=0, m=2, l=1, k=1: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 603.96it/s, init loss: 40.9091, avg. loss [951-1000]: 31.3371]
# Inferred GP parameters
# k_length         [0.1728 0.6316 1.7902]
# k_scale          1.1015000000000001
# noise            0.0714
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=0, m=2, l=1, k=2
# Number of samples used to train GP surrogate model for weights n=0, m=2, l=1, k=2: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:02<00:00, 385.99it/s, init loss: 45.9830, avg. loss [951-1000]: 38.9055]
# Inferred GP parameters
# k_length         [0.1826 0.6252 1.1998]
# k_scale          1.6643000000000001
# noise            0.1241
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=0, m=2, l=1, k=3
# Number of samples used to train GP surrogate model for weights n=0, m=2, l=1, k=3: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 567.92it/s, init loss: 52.3666, avg. loss [951-1000]: 45.3392]
# Inferred GP parameters
# k_length         [0.1868 0.6129 0.858 ]
# k_scale          2.4591000000000003
# noise            0.15990000000000001
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=0, m=2, l=2, k=0
# Number of samples used to train GP surrogate model for weights n=0, m=2, l=2, k=0: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 554.21it/s, init loss: 42.6738, avg. loss [951-1000]: 34.5393]
# Inferred GP parameters
# k_length         [0.1451 0.6045 1.567 ]
# k_scale          1.2378
# noise            0.0762
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=0, m=2, l=2, k=1
# Number of samples used to train GP surrogate model for weights n=0, m=2, l=2, k=1: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 583.51it/s, init loss: 47.7357, avg. loss [951-1000]: 41.1176]
# Inferred GP parameters
# k_length         [0.1598 0.6029 1.0101]
# k_scale          1.8418
# noise            0.116
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=0, m=2, l=2, k=2
# Number of samples used to train GP surrogate model for weights n=0, m=2, l=2, k=2: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 563.40it/s, init loss: 54.1074, avg. loss [951-1000]: 46.8894]
# Inferred GP parameters
# k_length         [0.1709 0.6015 0.7649]
# k_scale          2.6495
# noise            0.1499
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=0, m=2, l=2, k=3
# Number of samples used to train GP surrogate model for weights n=0, m=2, l=2, k=3: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:02<00:00, 408.90it/s, init loss: 61.7889, avg. loss [951-1000]: 52.0742]
# Inferred GP parameters
# k_length         [0.1815 0.6058 0.6962]
# k_scale          3.4765
# noise            0.23520000000000002
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=0, m=2, l=3, k=0
# Number of samples used to train GP surrogate model for weights n=0, m=2, l=3, k=0: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 593.25it/s, init loss: 50.4434, avg. loss [951-1000]: 43.7468]
# Inferred GP parameters
# k_length         [0.1367 0.5808 0.8779]
# k_scale          2.0982000000000003
# noise            0.0989
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=0, m=2, l=3, k=1
# Number of samples used to train GP surrogate model for weights n=0, m=2, l=3, k=1: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:02<00:00, 402.82it/s, init loss: 56.8031, avg. loss [951-1000]: 48.8804]
# Inferred GP parameters
# k_length         [0.1526 0.5913 0.7169]
# k_scale          2.8457000000000003
# noise            0.1572
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=0, m=2, l=3, k=2
# Number of samples used to train GP surrogate model for weights n=0, m=2, l=3, k=2: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 571.14it/s, init loss: 64.4727, avg. loss [951-1000]: 53.7740]
# Inferred GP parameters
# k_length         [0.1728 0.6118 0.6791]
# k_scale          3.5627
# noise            0.29550000000000004
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=0, m=2, l=3, k=3
# Number of samples used to train GP surrogate model for weights n=0, m=2, l=3, k=3: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 587.46it/s, init loss: 73.4521, avg. loss [951-1000]: 58.4160]
# Inferred GP parameters
# k_length         [0.1873 0.6332 0.6954]
# k_scale          4.1837
# noise            0.5067
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=0, m=3, l=0, k=0
# Number of samples used to train GP surrogate model for weights n=0, m=3, l=0, k=0: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 592.16it/s, init loss: 37.4049, avg. loss [951-1000]: 23.6359]
# Inferred GP parameters
# k_length         [0.1889 0.6318 1.5033]
# k_scale          0.7116
# noise            0.0451
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=0, m=3, l=0, k=1
# Number of samples used to train GP surrogate model for weights n=0, m=3, l=0, k=1: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 573.83it/s, init loss: 40.7765, avg. loss [951-1000]: 26.8806]
# Inferred GP parameters
# k_length         [0.1794 0.646  2.9757]
# k_scale          1.0744
# noise            0.0339
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=0, m=3, l=0, k=2
# Number of samples used to train GP surrogate model for weights n=0, m=3, l=0, k=2: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 533.78it/s, init loss: 45.4580, avg. loss [951-1000]: 33.6911]
# Inferred GP parameters
# k_length         [0.1711 0.5984 2.5939]
# k_scale          1.4645000000000001
# noise            0.0572
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=0, m=3, l=0, k=3
# Number of samples used to train GP surrogate model for weights n=0, m=3, l=0, k=3: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 592.52it/s, init loss: 51.4494, avg. loss [951-1000]: 40.9225]
# Inferred GP parameters
# k_length         [0.173  0.5858 1.8515]
# k_scale          2.0307
# noise            0.1149
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=0, m=3, l=1, k=0
# Number of samples used to train GP surrogate model for weights n=0, m=3, l=1, k=0: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:02<00:00, 367.54it/s, init loss: 41.7763, avg. loss [951-1000]: 28.7915]
# Inferred GP parameters
# k_length         [0.1562 0.6535 2.9427]
# k_scale          1.161
# noise            0.0323
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=0, m=3, l=1, k=1
# Number of samples used to train GP surrogate model for weights n=0, m=3, l=1, k=1: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 521.70it/s, init loss: 46.4458, avg. loss [951-1000]: 35.2181]
# Inferred GP parameters
# k_length         [0.1539 0.5898 2.4836]
# k_scale          1.5506
# noise            0.0555
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=0, m=3, l=1, k=2
# Number of samples used to train GP surrogate model for weights n=0, m=3, l=1, k=2: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:02<00:00, 496.99it/s, init loss: 52.4253, avg. loss [951-1000]: 42.0900]
# Inferred GP parameters
# k_length         [0.1608 0.579  1.7121]
# k_scale          2.137
# noise            0.11230000000000001
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=0, m=3, l=1, k=3
# Number of samples used to train GP surrogate model for weights n=0, m=3, l=1, k=3: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 591.80it/s, init loss: 59.7145, avg. loss [951-1000]: 48.1468]
# Inferred GP parameters
# k_length         [0.1689 0.5819 1.2333]
# k_scale          2.9029000000000003
# noise            0.1806
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=0, m=3, l=2, k=0
# Number of samples used to train GP surrogate model for weights n=0, m=3, l=2, k=0: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 592.57it/s, init loss: 48.3886, avg. loss [951-1000]: 37.8013]
# Inferred GP parameters
# k_length         [0.1367 0.5778 2.2192]
# k_scale          1.7080000000000002
# noise            0.058800000000000005
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=0, m=3, l=2, k=1
# Number of samples used to train GP surrogate model for weights n=0, m=3, l=2, k=1: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 595.70it/s, init loss: 54.3561, avg. loss [951-1000]: 43.9776]
# Inferred GP parameters
# k_length         [0.1449 0.5653 1.5241]
# k_scale          2.3149
# noise            0.1092
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=0, m=3, l=2, k=2
# Number of samples used to train GP surrogate model for weights n=0, m=3, l=2, k=2: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 588.77it/s, init loss: 61.6333, avg. loss [951-1000]: 49.5812]
# Inferred GP parameters
# k_length         [0.1568 0.5751 1.1362]
# k_scale          3.0793
# noise            0.186
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=0, m=3, l=2, k=3
# Number of samples used to train GP surrogate model for weights n=0, m=3, l=2, k=3: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 547.31it/s, init loss: 70.2205, avg. loss [951-1000]: 54.6744]
# Inferred GP parameters
# k_length         [0.1693 0.5896 0.9945]
# k_scale          3.8634000000000004
# noise            0.317
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=0, m=3, l=3, k=0
# Number of samples used to train GP surrogate model for weights n=0, m=3, l=3, k=0: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 579.45it/s, init loss: 57.2418, avg. loss [951-1000]: 46.2843]
# Inferred GP parameters
# k_length         [0.1315 0.557  1.373 ]
# k_scale          2.556
# noise            0.11380000000000001
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=0, m=3, l=3, k=1
# Number of samples used to train GP surrogate model for weights n=0, m=3, l=3, k=1: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:02<00:00, 336.70it/s, init loss: 64.5071, avg. loss [951-1000]: 51.4480]
# Inferred GP parameters
# k_length         [0.1451 0.5701 1.0937]
# k_scale          3.2738
# noise            0.21300000000000002
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=0, m=3, l=3, k=2
# Number of samples used to train GP surrogate model for weights n=0, m=3, l=3, k=2: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 594.37it/s, init loss: 73.0823, avg. loss [951-1000]: 56.2915]
# Inferred GP parameters
# k_length         [0.1627 0.5939 0.99  ]
# k_scale          3.9846000000000004
# noise            0.38220000000000004
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=0, m=3, l=3, k=3
# Number of samples used to train GP surrogate model for weights n=0, m=3, l=3, k=3: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 555.32it/s, init loss: 82.9674, avg. loss [951-1000]: 60.7567]
# Inferred GP parameters
# k_length         [0.1766 0.6159 0.9579]
# k_scale          4.657900000000001
# noise            0.6055
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=1, m=0, l=0, k=0
# Number of samples used to train GP surrogate model for weights n=1, m=0, l=0, k=0: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 580.57it/s, init loss: 31.7135, avg. loss [951-1000]: 1.1702]
# Inferred GP parameters
# k_length         [0.7277 0.9629 1.1457]
# k_scale          0.16570000000000001
# noise            0.025
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=1, m=0, l=0, k=1
# Number of samples used to train GP surrogate model for weights n=1, m=0, l=0, k=1: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 534.44it/s, init loss: 32.4743, avg. loss [951-1000]: 9.2897]
# Inferred GP parameters
# k_length         [0.5174 0.8763 1.2405]
# k_scale          0.29910000000000003
# noise            0.0378
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=1, m=0, l=0, k=2
# Number of samples used to train GP surrogate model for weights n=1, m=0, l=0, k=2: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:02<00:00, 477.08it/s, init loss: 34.5449, avg. loss [951-1000]: 21.3859]
# Inferred GP parameters
# k_length         [0.3942 0.803  0.9711]
# k_scale          0.6036
# noise            0.0771
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=1, m=0, l=0, k=3
# Number of samples used to train GP surrogate model for weights n=1, m=0, l=0, k=3: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 596.26it/s, init loss: 37.9254, avg. loss [951-1000]: 31.1083]
# Inferred GP parameters
# k_length         [0.3143 0.7245 0.6989]
# k_scale          1.1696
# noise            0.1051
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=1, m=0, l=1, k=0
# Number of samples used to train GP surrogate model for weights n=1, m=0, l=1, k=0: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:02<00:00, 345.87it/s, init loss: 32.9080, avg. loss [951-1000]: 14.4233]
# Inferred GP parameters
# k_length         [0.4234 1.1069 1.0668]
# k_scale          0.3134
# noise            0.0599
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=1, m=0, l=1, k=1
# Number of samples used to train GP surrogate model for weights n=1, m=0, l=1, k=1: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 571.77it/s, init loss: 34.9667, avg. loss [951-1000]: 23.9093]
# Inferred GP parameters
# k_length         [0.3744 0.9772 0.9756]
# k_scale          0.5774
# noise            0.10740000000000001
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=1, m=0, l=1, k=2
# Number of samples used to train GP surrogate model for weights n=1, m=0, l=1, k=2: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 560.89it/s, init loss: 38.3352, avg. loss [951-1000]: 32.6809]
# Inferred GP parameters
# k_length         [0.3182 0.8172 0.7077]
# k_scale          1.0799
# noise            0.1501
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=1, m=0, l=1, k=3
# Number of samples used to train GP surrogate model for weights n=1, m=0, l=1, k=3: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 611.41it/s, init loss: 43.0136, avg. loss [951-1000]: 39.8273]
# Inferred GP parameters
# k_length         [0.2713 0.6799 0.5334]
# k_scale          1.9999
# noise            0.12240000000000001
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=1, m=0, l=2, k=0
# Number of samples used to train GP surrogate model for weights n=1, m=0, l=2, k=0: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 598.35it/s, init loss: 36.3434, avg. loss [951-1000]: 28.5328]
# Inferred GP parameters
# k_length         [0.3262 1.0754 0.9267]
# k_scale          0.6126
# noise            0.1617
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=1, m=0, l=2, k=1
# Number of samples used to train GP surrogate model for weights n=1, m=0, l=2, k=1: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 576.39it/s, init loss: 39.7000, avg. loss [951-1000]: 35.5873]
# Inferred GP parameters
# k_length         [0.3143 0.9589 0.8325]
# k_scale          0.9804
# noise            0.2354
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=1, m=0, l=2, k=2
# Number of samples used to train GP surrogate model for weights n=1, m=0, l=2, k=2: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 569.89it/s, init loss: 44.3664, avg. loss [951-1000]: 41.9387]
# Inferred GP parameters
# k_length         [0.2585 0.7073 0.4884]
# k_scale          2.0432
# noise            0.1573
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=1, m=0, l=2, k=3
# Number of samples used to train GP surrogate model for weights n=1, m=0, l=2, k=3: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:02<00:00, 493.07it/s, init loss: 50.3426, avg. loss [951-1000]: 47.4342]
# Inferred GP parameters
# k_length         [0.2433 0.6519 0.4595]
# k_scale          3.0224
# noise            0.1547
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=1, m=0, l=3, k=0
# Number of samples used to train GP surrogate model for weights n=1, m=0, l=3, k=0: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 585.36it/s, init loss: 42.0197, avg. loss [951-1000]: 39.2197]
# Inferred GP parameters
# k_length         [0.2892 1.0257 0.8389]
# k_scale          1.0217
# noise            0.3219
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=1, m=0, l=3, k=1
# Number of samples used to train GP surrogate model for weights n=1, m=0, l=3, k=1: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:02<00:00, 357.51it/s, init loss: 46.6741, avg. loss [951-1000]: 44.7082]
# Inferred GP parameters
# k_length         [0.2453 0.7504 0.475 ]
# k_scale          2.0597000000000003
# noise            0.2318
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=1, m=0, l=3, k=2
# Number of samples used to train GP surrogate model for weights n=1, m=0, l=3, k=2: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 571.53it/s, init loss: 52.6384, avg. loss [951-1000]: 49.5110]
# Inferred GP parameters
# k_length         [0.2192 0.6609 0.4309]
# k_scale          3.1774
# noise            0.1749
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=1, m=0, l=3, k=3
# Number of samples used to train GP surrogate model for weights n=1, m=0, l=3, k=3: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 534.49it/s, init loss: 59.9126, avg. loss [951-1000]: 54.1473]
# Inferred GP parameters
# k_length         [0.2344 0.6668 0.4415]
# k_scale          3.9271000000000003
# noise            0.301
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=1, m=1, l=0, k=0
# Number of samples used to train GP surrogate model for weights n=1, m=1, l=0, k=0: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 529.30it/s, init loss: 32.5275, avg. loss [951-1000]: 9.5970]
# Inferred GP parameters
# k_length         [0.4131 0.7368 1.2465]
# k_scale          0.2612
# noise            0.0379
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=1, m=1, l=0, k=1
# Number of samples used to train GP surrogate model for weights n=1, m=1, l=0, k=1: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 584.36it/s, init loss: 34.1938, avg. loss [951-1000]: 17.1582]
# Inferred GP parameters
# k_length         [0.3198 0.7292 1.7732]
# k_scale          0.5293
# noise            0.0463
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=1, m=1, l=0, k=2
# Number of samples used to train GP surrogate model for weights n=1, m=1, l=0, k=2: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:02<00:00, 393.51it/s, init loss: 37.1700, avg. loss [951-1000]: 26.8098]
# Inferred GP parameters
# k_length         [0.2757 0.7035 1.5067]
# k_scale          0.8968
# noise            0.08120000000000001
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=1, m=1, l=0, k=3
# Number of samples used to train GP surrogate model for weights n=1, m=1, l=0, k=3: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 552.15it/s, init loss: 41.4561, avg. loss [951-1000]: 35.3172]
# Inferred GP parameters
# k_length         [0.2539 0.6772 0.9939]
# k_scale          1.4832
# noise            0.1206
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=1, m=1, l=1, k=0
# Number of samples used to train GP surrogate model for weights n=1, m=1, l=1, k=0: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:02<00:00, 407.91it/s, init loss: 34.8056, avg. loss [951-1000]: 21.1494]
# Inferred GP parameters
# k_length         [0.2924 0.8983 1.4333]
# k_scale          0.5630000000000001
# noise            0.0716
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=1, m=1, l=1, k=1
# Number of samples used to train GP surrogate model for weights n=1, m=1, l=1, k=1: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 598.93it/s, init loss: 37.7699, avg. loss [951-1000]: 29.2286]
# Inferred GP parameters
# k_length         [0.2683 0.8027 1.3764]
# k_scale          0.9189
# noise            0.11230000000000001
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=1, m=1, l=1, k=2
# Number of samples used to train GP surrogate model for weights n=1, m=1, l=1, k=2: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 579.19it/s, init loss: 42.0440, avg. loss [951-1000]: 36.8796]
# Inferred GP parameters
# k_length         [0.2509 0.7346 1.0282]
# k_scale          1.4480000000000002
# noise            0.162
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=1, m=1, l=1, k=3
# Number of samples used to train GP surrogate model for weights n=1, m=1, l=1, k=3: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 568.61it/s, init loss: 47.6279, avg. loss [951-1000]: 43.3951]
# Inferred GP parameters
# k_length         [0.2312 0.6528 0.6814]
# k_scale          2.4194
# noise            0.1433
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=1, m=1, l=2, k=0
# Number of samples used to train GP surrogate model for weights n=1, m=1, l=2, k=0: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 577.89it/s, init loss: 39.3247, avg. loss [951-1000]: 33.0292]
# Inferred GP parameters
# k_length         [0.2546 0.8849 1.1997]
# k_scale          0.9647
# noise            0.1678
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=1, m=1, l=2, k=1
# Number of samples used to train GP surrogate model for weights n=1, m=1, l=2, k=1: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:02<00:00, 491.61it/s, init loss: 43.5868, avg. loss [951-1000]: 39.4626]
# Inferred GP parameters
# k_length         [0.248  0.8094 1.0662]
# k_scale          1.4306
# noise            0.23340000000000002
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ...
# Number of samples used to train GP surrogate model for weights n=3, m=3, l=0, k=1: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 543.34it/s, init loss: 48.2810, avg. loss [951-1000]: 40.7295]
# Inferred GP parameters
# k_length         [0.2853 0.6162 1.4579]
# k_scale          2.1559
# noise            0.17250000000000001
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=3, m=3, l=0, k=2
# Number of samples used to train GP surrogate model for weights n=3, m=3, l=0, k=2: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:03<00:00, 316.76it/s, init loss: 53.2801, avg. loss [951-1000]: 44.1603]
# Inferred GP parameters
# k_length         [0.2541 0.6002 1.6409]
# k_scale          2.7196000000000002
# noise            0.17980000000000002
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=3, m=3, l=0, k=3
# Number of samples used to train GP surrogate model for weights n=3, m=3, l=0, k=3: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 550.96it/s, init loss: 59.5890, avg. loss [951-1000]: 48.2794]
# Inferred GP parameters
# k_length         [0.2358 0.5839 1.6246]
# k_scale          3.3609
# noise            0.2141
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=3, m=3, l=1, k=0
# Number of samples used to train GP surrogate model for weights n=3, m=3, l=1, k=0: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 560.06it/s, init loss: 49.1854, avg. loss [951-1000]: 42.8062]
# Inferred GP parameters
# k_length         [0.2601 0.681  1.3466]
# k_scale          2.1814
# noise            0.2184
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=3, m=3, l=1, k=1
# Number of samples used to train GP surrogate model for weights n=3, m=3, l=1, k=1: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 564.90it/s, init loss: 54.1725, avg. loss [951-1000]: 45.9959]
# Inferred GP parameters
# k_length         [0.2131 0.6309 1.5182]
# k_scale          2.7757
# noise            0.19790000000000002
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=3, m=3, l=1, k=2
# Number of samples used to train GP surrogate model for weights n=3, m=3, l=1, k=2: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 544.28it/s, init loss: 60.4695, avg. loss [951-1000]: 49.7993]
# Inferred GP parameters
# k_length         [0.2069 0.611  1.5104]
# k_scale          3.43
# noise            0.23550000000000001
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=3, m=3, l=1, k=3
# Number of samples used to train GP surrogate model for weights n=3, m=3, l=1, k=3: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:02<00:00, 334.33it/s, init loss: 68.0763, avg. loss [951-1000]: 53.9134]
# Inferred GP parameters
# k_length         [0.216  0.6131 1.4043]
# k_scale          4.1919
# noise            0.32130000000000003
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=3, m=3, l=2, k=0
# Number of samples used to train GP surrogate model for weights n=3, m=3, l=2, k=0: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:04<00:00, 226.75it/s, init loss: 56.0199, avg. loss [951-1000]: 47.9093]
# Inferred GP parameters
# k_length         [0.1393 0.6064 1.475 ]
# k_scale          2.9155
# noise            0.1416
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=3, m=3, l=2, k=1
# Number of samples used to train GP surrogate model for weights n=3, m=3, l=2, k=1: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:02<00:00, 447.67it/s, init loss: 62.3049, avg. loss [951-1000]: 51.6233]
# Inferred GP parameters
# k_length         [0.1687 0.6116 1.4243]
# k_scale          3.5623
# noise            0.2441
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=3, m=3, l=2, k=2
# Number of samples used to train GP surrogate model for weights n=3, m=3, l=2, k=2: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 564.55it/s, init loss: 69.8998, avg. loss [951-1000]: 55.5290]
# Inferred GP parameters
# k_length         [0.2008 0.6374 1.3552]
# k_scale          4.2741
# noise            0.37870000000000004
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=3, m=3, l=2, k=3
# Number of samples used to train GP surrogate model for weights n=3, m=3, l=2, k=3: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 549.89it/s, init loss: 78.8045, avg. loss [951-1000]: 59.4099]
# Inferred GP parameters
# k_length         [0.2153 0.6473 1.2873]
# k_scale          5.0336
# noise            0.5273
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=3, m=3, l=3, k=0
# Number of samples used to train GP surrogate model for weights n=3, m=3, l=3, k=0: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 561.49it/s, init loss: 65.0953, avg. loss [951-1000]: 53.6833]
# Inferred GP parameters
# k_length         [0.15   0.6209 1.3717]
# k_scale          3.7304000000000004
# noise            0.2877
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=3, m=3, l=3, k=1
# Number of samples used to train GP surrogate model for weights n=3, m=3, l=3, k=1: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 575.16it/s, init loss: 72.6782, avg. loss [951-1000]: 57.4165]
# Inferred GP parameters
# k_length         [0.1902 0.6613 1.313 ]
# k_scale          4.3721000000000005
# noise            0.46480000000000005
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=3, m=3, l=3, k=2
# Number of samples used to train GP surrogate model for weights n=3, m=3, l=3, k=2: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:02<00:00, 345.30it/s, init loss: 81.5709, avg. loss [951-1000]: 61.0319]
# Inferred GP parameters
# k_length         [0.2104 0.6781 1.2662]
# k_scale          5.0722000000000005
# noise            0.637
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# ============================================================
# Running weights: n=3, m=3, l=3, k=3
# Number of samples used to train GP surrogate model for weights n=3, m=3, l=3, k=3: 29
# Training Model (this may take some time).
# 100%|██████████| 1000/1000 [00:01<00:00, 587.02it/s, init loss: 91.7735, avg. loss [951-1000]: 64.5964]
# Inferred GP parameters
# k_length         [0.2191 0.6838 1.2303]
# k_scale          5.7803
# noise            0.8409000000000001
# Getting Model Predictions.
# Calculating acquisition.
# Getting parameter samples.
#
# Summary:
#      n  m  l  k    alpha    beta    gamma   delta  best_pred_score  \
# 0    0  0  0  0   0.0000  0.0000   0.0000  0.0000         0.000000
# 1    0  0  0  1   0.0000  0.0000   0.0000  0.0338         0.154341
# 2    0  0  0  2   0.0000  0.0000   0.0000  0.0676         0.208778
# 3    0  0  0  3   0.0000  0.0000   0.0000  0.1014         0.210799
# 4    0  0  1  0   0.0000  0.0000   4.3879  0.0000         0.083731
# ..  .. .. .. ..      ...     ...      ...     ...              ...
# 251  3  3  2  3  18.1818  0.2628   8.7758  0.1014         1.030921
# 252  3  3  3  0  18.1818  0.2628  13.1637  0.0000         0.464434
# 253  3  3  3  1  18.1818  0.2628  13.1637  0.0338         0.812370
# 254  3  3  3  2  18.1818  0.2628  13.1637  0.0676         1.019695
# 255  3  3  3  3  18.1818  0.2628  13.1637  0.1014         1.223464
#
#      best_pred_log10P  best_pred_pressure_Torr  best_pred_temperature_C  \
# 0           -7.522879             3.000000e-08               500.000000
# 1           -4.322879             4.754680e-05               500.000000
# 2           -7.522879             3.000000e-08               500.000000
# 3           -7.522879             3.000000e-08               500.000000
# 4           -5.322879             4.754680e-06               500.000000
# ..                ...                      ...                      ...
# 251         -6.022879             9.486833e-07               819.999993
# 252         -4.222879             5.985787e-05               500.000000
# 253         -5.922879             1.194322e-06               819.999993
# 254         -5.922879             1.194322e-06               819.999993
# 255         -6.022879             9.486833e-07               819.999993
#
#      best_pred_fluence_Jpcm2  meas_best_score  meas_best_log10P  \
# 0                   0.800000         0.000000         -7.301030
# 1                   2.099999         0.138580         -5.017729
# 2                   2.099999         0.277160         -5.017729
# 3                   2.099999         0.415740         -5.017729
# 4                   0.800000         0.118035         -5.017729
# ..                       ...              ...               ...
# 251                 0.800000         0.949154         -4.657577
# 252                 0.800000         0.507199         -4.657577
# 253                 0.800000         0.699859         -4.657577
# 254                 0.800000         0.892519         -4.657577
# 255                 0.800000         1.085179         -4.657577
#
#      meas_best_pressure_Torr  meas_best_temperature_C  meas_best_fluence_Jpcm2
# 0               5.000000e-08                    710.0                      1.0
# 1               9.600002e-06                    715.0                      2.0
# 2               9.600002e-06                    715.0                      2.0
# 3               9.600002e-06                    715.0                      2.0
# 4               9.600002e-06                    810.0                      1.0
# ..                       ...                      ...                      ...
# 251             2.200000e-05                    700.0                      1.0
# 252             2.200000e-05                    700.0                      1.0
# 253             2.200000e-05                    700.0                      1.0
# 254             2.200000e-05                    700.0                      1.0
# 255             2.200000e-05                    700.0                      1.0
#
# [256 rows x 18 columns]
# Saved best_points_by_weights.csv/.xlsx to current directory
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="16ef9d38-d889-433f-9277-c2c4b9d9f8b4" class="plotly-graph-div" style="height:700px; width:1100px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("16ef9d38-d889-433f-9277-c2c4b9d9f8b4")) {                    Plotly.newPlot(                        "16ef9d38-d889-433f-9277-c2c4b9d9f8b4",                        [{"hovertext":["n=0, m=0, l=0, k=0\u003cbr\u003escore=0.0000\u003cbr\u003eP=3.00e-08 Torr\u003cbr\u003eT=500 C\u003cbr\u003eF=0.80 J\u002fcm^2","n=0, m=0, l=0, k=1\u003cbr\u003escore=0.1543\u003cbr\u003eP=4.75e-05 Torr\u003cbr\u003eT=500 C\u003cbr\u003eF=2.10 J\u002fcm^2","n=0, m=0, l=0, k=2\u003cbr\u003escore=0.2088\u003cbr\u003eP=3.00e-08 Torr\u003cbr\u003eT=500 C\u003cbr\u003eF=2.10 J\u002fcm^2","n=0, m=0, l=0, k=3\u003cbr\u003escore=0.2108\u003cbr\u003eP=3.00e-08 Torr\u003cbr\u003eT=500 C\u003cbr\u003eF=2.10 J\u002fcm^2","n=0, m=0, l=1, k=0\u003cbr\u003escore=0.0837\u003cbr\u003eP=4.75e-06 Torr\u003cbr\u003eT=500 C\u003cbr\u003eF=0.80 J\u002fcm^2","n=0, m=0, l=1, k=1\u003cbr\u003escore=0.1960\u003cbr\u003eP=3.00e-08 Torr\u003cbr\u003eT=500 C\u003cbr\u003eF=2.10 J\u002fcm^2","n=0, m=0, l=1, k=2\u003cbr\u003escore=0.2045\u003cbr\u003eP=3.00e-08 Torr\u003cbr\u003eT=500 C\u003cbr\u003eF=2.10 J\u002fcm^2","n=0, m=0, l=1, k=3\u003cbr\u003escore=0.2345\u003cbr\u003eP=3.00e-08 Torr\u003cbr\u003eT=500 C\u003cbr\u003eF=2.10 J\u002fcm^2","n=0, m=0, l=2, k=0\u003cbr\u003escore=0.1494\u003cbr\u003eP=3.00e-08 Torr\u003cbr\u003eT=500 C\u003cbr\u003eF=2.10 J\u002fcm^2","n=0, m=0, l=2, k=1\u003cbr\u003escore=0.1830\u003cbr\u003eP=3.00e-08 Torr\u003cbr\u003eT=500 C\u003cbr\u003eF=2.10 J\u002fcm^2","n=0, m=0, l=2, k=2\u003cbr\u003escore=0.2200\u003cbr\u003eP=3.00e-08 Torr\u003cbr\u003eT=500 C\u003cbr\u003eF=2.10 J\u002fcm^2","n=0, m=0, l=2, k=3\u003cbr\u003escore=0.2681\u003cbr\u003eP=3.00e-08 Torr\u003cbr\u003eT=500 C\u003cbr\u003eF=2.10 J\u002fcm^2","n=0, m=0, l=3, k=0\u003cbr\u003escore=0.1414\u003cbr\u003eP=3.00e-08 Torr\u003cbr\u003eT=820 C\u003cbr\u003eF=2.10 J\u002fcm^2","n=0, m=0, l=3, k=1\u003cbr\u003escore=0.1766\u003cbr\u003eP=3.00e-08 Torr\u003cbr\u003eT=820 C\u003cbr\u003eF=2.10 J\u002fcm^2","n=0, m=0, l=3, k=2\u003cbr\u003escore=0.2390\u003cbr\u003eP=3.00e-08 Torr\u003cbr\u003eT=820 C\u003cbr\u003eF=2.10 J\u002fcm^2","n=0, m=0, l=3, k=3\u003cbr\u003escore=0.3015\u003cbr\u003eP=3.00e-08 Torr\u003cbr\u003eT=500 C\u003cbr\u003eF=2.10 J\u002fcm^2","n=0, m=1, l=0, k=0\u003cbr\u003escore=-0.0481\u003cbr\u003eP=7.54e-06 Torr\u003cbr\u003eT=560 C\u003cbr\u003eF=0.80 J\u002fcm^2","n=0, m=1, l=0, k=1\u003cbr\u003escore=0.1106\u003cbr\u003eP=3.00e-05 Torr\u003cbr\u003eT=500 C\u003cbr\u003eF=2.10 J\u002fcm^2","n=0, m=1, l=0, k=2\u003cbr\u003escore=0.2048\u003cbr\u003eP=4.75e-05 Torr\u003cbr\u003eT=500 C\u003cbr\u003eF=2.10 J\u002fcm^2","n=0, m=1, l=0, k=3\u003cbr\u003escore=0.2473\u003cbr\u003eP=3.00e-08 Torr\u003cbr\u003eT=500 C\u003cbr\u003eF=2.10 J\u002fcm^2","n=0, m=1, l=1, k=0\u003cbr\u003escore=0.0531\u003cbr\u003eP=1.50e-05 Torr\u003cbr\u003eT=500 C\u003cbr\u003eF=1.50 J\u002fcm^2","n=0, m=1, l=1, k=1\u003cbr\u003escore=0.1740\u003cbr\u003eP=2.38e-05 Torr\u003cbr\u003eT=500 C\u003cbr\u003eF=2.10 J\u002fcm^2","n=0, m=1, l=1, k=2\u003cbr\u003escore=0.2279\u003cbr\u003eP=3.00e-08 Torr\u003cbr\u003eT=500 C\u003cbr\u003eF=2.10 J\u002fcm^2","n=0, m=1, l=1, k=3\u003cbr\u003escore=0.2565\u003cbr\u003eP=3.00e-08 Torr\u003cbr\u003eT=500 C\u003cbr\u003eF=2.10 J\u002fcm^2","n=0, m=1, l=2, k=0\u003cbr\u003escore=0.1624\u003cbr\u003eP=1.50e-05 Torr\u003cbr\u003eT=500 C\u003cbr\u003eF=1.40 J\u002fcm^2","n=0, m=1, l=2, k=1\u003cbr\u003escore=0.2027\u003cbr\u003eP=3.00e-08 Torr\u003cbr\u003eT=500 C\u003cbr\u003eF=2.10 J\u002fcm^2","n=0, m=1, l=2, k=2\u003cbr\u003escore=0.2342\u003cbr\u003eP=3.00 ...
# Done. Check the CSV/XLSX for the full table of results.
